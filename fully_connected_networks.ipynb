# %% [markdown]
# # CS 6476 Assignment 2 | Part 1: Fully-Connected Neural Networks for Image Classification

# %% [markdown]
# # AIM
#  The aim of this assignment is to implement a fully-connected neural network from scratch on CIFAR-10 image classification dataset.

# %% [markdown]
# # Summary
# The goal of this part of the assignment is to provide hands-on experience with coding fully connected neural networks from scratch in pytorch. The structure of the coding part of the assignment is modular to iterate over the components involved. Finally we will use, optimize and train our final model on CIFAR-10 image classification dataset, assess the accuracy of our model and answer some questions regarding the same. For you understanding certain blogs have been provided in the notebook. We believe they can help you better understand concepts that you are about to implement. More such resources for reading will be provided over ed-discussions.
# ## Learning Objectives
# - First Prinicipal coding of FC-NN
# - Develope basic understanding of components of an end-end FC-NN
# - Develope basic uderstanding of regularization techniques and model optimizers
# - Develope basic understanding on how to fine tune a model using validation set
#
#
#
# ## Grading Schema
# This part of the assignment will be graded out of 100. A good representative of the testcases are already provided in the notebook.
# - Linear Layer (10)
# - ReLU Layer (10)
# - Convinence Module (10)
# - Two-Layer-Network (15)
# - Multi-Layer-Network (15)
# - Momentum Optimizer (10)
# - Dropout (10)
# - Optimal Fine Tuned Model (20)
#
#
# ## Time Commitement
# This part of the assignment should take about 6 hrs of effort to finish. Half of the time estimate is for the associated readings to get a better understanding of the concepts and how it can be coded.
#
#
#
# ## Computational Requirements
# This part of the assignment should not take more than 20 mins in total to execute each part, including training of the optimal model. These estimates are for code running on CPU. Students can see significantly faster results if running on GPU. Refer to `google colab` setup to see how you can get free access to GPU to execute the assignment if you wish to. (note it is not needed, and CPU execution executes in reasonable time and wont effect your final output or grades).

# %% [markdown]
# # Setup
# If running on local system install the packages through following commands.
# ```
# pip install opencv-python
# pip install torchvision
# pip install torch
# ```

# %% [markdown]
# ## Colab Setup
# First, run the following cell to load the "autoreload" extension. The "autoreload" extension allows you to automatically reload (re-import) Python modules that you've imported or defined when they change. This is particularly useful when you are actively developing or modifying code in external modules and want those changes to be automatically reflected in your notebook without manually restarting the kernel. Those not running colab avoid running the cells associated to `colab setup`

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a CV2023 folder and put all the files under A2 folder, then 'CV2023/A2'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CS 6476 Intro to Computer Vision/Assignment 2' #enter file name as the above example
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['simple_models.py', 'a2_helper.py', 'cs6476', '__pycache__', 'simple_models.ipynb', 'resnet.pth', 'transfer_learning.ipynb', 'convolutional_networks.py', 'convolutional_networks.ipynb', 'fully_connected_networks.py', 'fully_connected_networks.ipynb']

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run the following cell to allow us to import from the .py files of this part of the assignment. If it works correctly, it should print the message:
# ```
# Hello from fully_connected_neural_networks.py!
# Hello from a2_helper.py!
# ```

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from fully_connected_networks import hello_fully_connected_networks
hello_fully_connected_networks()

from a2_helper import hello_helper
hello_helper()

FC_networks_path = os.path.join(GOOGLE_DRIVE_PATH, 'fully_connected_networks.py')
FC_networks_edit_time = time.ctime(os.path.getmtime(FC_networks_path))
print('fully_connected_networks.py last edited on %s' % FC_networks_edit_time)
# Out:
# Hello from fully_connected_neural_networks.py!
# Hello from a2_helper.py!
# fully_connected_networks.py last edited on Mon Sep 18 17:09:50 2023

# %% [markdown]
# On colab install dependecies using:
# ```
# !pip install opencv-python
# !pip install torchvision
# !pip install torch
# ```

# %% [markdown]
# # Imports
# Import requisit packages to work with the provided files for part-1 of the assignment.

# %%
import cs6476
import torch
import torchvision
import matplotlib.pyplot as plt
# %matplotlib inline
from cs6476 import Solver

plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %%
DEVICE = 'cpu'

# %% [markdown]
# Run this cell to check if you are using a GPU. Don't use GPU if you want to save on your daily GPU usage. We recommend you to save it for the Part 2.

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print('Good to go!')
else:
  print('If you want to use GPU then set it via Edit -> Notebook Settings -> Hardware accelerator -> T4 GPU')
# Out:
# If you want to use GPU then set it via Edit -> Notebook Settings -> Hardware accelerator -> T4 GPU

# %% [markdown]
# IMPORTANT: If you have reached the GPU usage limit then 'connect without GPU' and change the DEVICE variable in the below cell to 'cpu'. Else make sure to set DEVICE to 'cuda'

# %%
 DEVICE = 'cpu'
# uncomment above if GPU is not avaible

 #DEVICE = 'cuda'
# uncomment above if gpu is avaible

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Load and Visualize the CIFAR-10 dataset
# We will first load the CIFAR-10 dataset. The utility function `cs6476.data.preprocess_cifar10()` returns the entire CIFAR-10 dataset as a set of six **Torch tensors** while also preprocessing the RGB images. We then split the data into 3 components, Train, Validate and Test.
#
# - `X_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `X_val` contains all validation images
# - `y_val` contains all validation labels
# - Note: The seed value should remain untouched while coding your experiments, to ensure consistency in results on gradescope.
#
# - To know more about CIFAR datasets read https://www.cs.toronto.edu/~kriz/cifar.html
# - Please note that you have to use your `gtid` to set seed for all experiments and code. It will be crucial for accurate testing over gradescope

# %%
cs6476.utils.reset_seed(903322690)
data_dict = cs6476.data.preprocess_cifar10(cuda=False, dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 98817696.13it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])

# %% [markdown]
# # Fully-connected neural networks

# %% [markdown]
# In this assignment we will implement fully-connected networks using a modular approach. First We will implement a forward and backward function such that we can easily combine a combination of them to build classifiers with different architectures. In addition to implementing fully-connected networks of arbitrary depth, we will also explore different rules for optimization, and Dropout as a regularizer.
#
# To validate our implementation, we have provided testing code for each module. The flow of the notebook is setup in such a fashion as to assist with the order of implementation and to debug code. We also provide visualization modules to test the performance of the model. Finally we ask the students to implment both a 2 layer Fully-Connected NN and an aribtrary depth Fully-Connected NN (with parameters of choice) to test the performance.

# %% [markdown]
# # Linear layer

# %% [markdown]
# For each layer we implement, we will define a class with two static methods `forward` and `backward` (already implemented). The class structure is currently provided in `fully_connected_layers.py`, you will be implementing both the `forward` and `backward` methods.
#
# You can read the following blog ot get a better understanding of the entire process: https://theneuralblog.com/forward-pass-backpropagation-example/

# %% [markdown]
# ## Linear layer: forward
# Test your implementation of `Linear.forward` using below code. You should see errors less than `1e-7`. Use Device as 'cuda' if you have access to GPU.
# - you have to implement `out = XW + b`

# %%
from fully_connected_networks import Linear

# Test the Linear.forward function
num_inputs = 2
input_shape = torch.tensor((4, 5, 6))
output_dim = 3

input_size = num_inputs * torch.prod(input_shape)
weight_size = output_dim * torch.prod(input_shape)

x = torch.linspace(-0.1, 0.5, steps=input_size, dtype=torch.float64,device='cpu')
w = torch.linspace(-0.2, 0.3, steps=weight_size, dtype=torch.float64,device='cpu')
b = torch.linspace(-0.3, 0.1, steps=output_dim, dtype=torch.float64,device='cpu')
x = x.reshape(num_inputs, *input_shape)
w = w.reshape(torch.prod(input_shape), output_dim)

out, _ = Linear.forward(x, w, b)
correct_out = torch.tensor([[1.49834984, 1.70660150, 1.91485316],
                            [3.25553226, 3.51413301, 3.77273372]]
                            ).double()#.cuda() // uncomment .cuda() if you have access to gpu

print('Testing Linear.forward function:')
print('difference: ', cs6476.grad.rel_error(out, correct_out))
# Out:
# Testing Linear.forward function:
# difference:  3.683042929747526e-08

# %% [markdown]
# ## Linear layer: backward
# We have already provided the code for `Linear.backward`. Test the overall implementation using below code. You should see errors less than `1e-7`. Use Device as 'cuda' if you have access to GPU.

# %%
from fully_connected_networks import Linear

# Test the Linear.backward function
cs6476.utils.reset_seed(903322690)
x = torch.randn(10, 2, 3, dtype=torch.float64)#, device='cuda'
w = torch.randn(6, 5, dtype=torch.float64)
b = torch.randn(5, dtype=torch.float64)
dout = torch.randn(10, 5, dtype=torch.float64)

dx_num = cs6476.grad.compute_numeric_gradient(lambda x: Linear.forward(x, w, b)[0], x, dout)
dw_num = cs6476.grad.compute_numeric_gradient(lambda w: Linear.forward(x, w, b)[0], w, dout)
db_num = cs6476.grad.compute_numeric_gradient(lambda b: Linear.forward(x, w, b)[0], b, dout)

_, cache = Linear.forward(x, w, b)
dx, dw, db = Linear.backward(dout, cache)

# The error should be around e-10 or less
print('Testing Linear.backward function:')
print('dx error: ', cs6476.grad.rel_error(dx_num, dx))
print('dw error: ', cs6476.grad.rel_error(dw_num, dw))
print('db error: ', cs6476.grad.rel_error(db_num, db))
# Out:
# Testing Linear.backward function:
# dx error:  7.715295572293721e-10
# dw error:  7.0752475833259e-10
# db error:  4.621820780382342e-10

# %% [markdown]
# # ReLU activation

# %% [markdown]
# We will now implement the ReLU nonlinearity. The class structure can be found in `fully_connected_networks.py`
#
# Brief Idea about ReLU and why it is a good activation function: https://www.mygreatlearning.com/blog/relu-activation-function/

# %% [markdown]
# ## ReLU activation: forward
# Test your implementation of `ReLU.forward` using below code. You should see errors less than `1e-8`. Use Device as 'cuda' if you have access to GPU.
# - you have to implement `out = max(0,x)`

# %%
from fully_connected_networks import ReLU

cs6476.utils.reset_seed(903322690)
x = torch.linspace(-0.5, 0.5, steps=12, dtype=torch.float64,device='cpu')
x = x.reshape(3, 4)

out, _ = ReLU.forward(x)
correct_out = torch.tensor([[ 0.,          0.,          0.,          0.,        ],
                            [ 0.,          0.,          0.04545455,  0.13636364,],
                            [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]],
                            dtype=torch.float64,device='cpu')

print('Testing ReLU.forward function:')
print('difference: ', cs6476.grad.rel_error(out, correct_out))
# Out:
# Testing ReLU.forward function:
# difference:  4.5454545613554664e-09

# %% [markdown]
# ## ReLU activation: backward
# We have already provided the code for `ReLU.backward`. Test the implementation of `ReLU.backward` in your overall code flow using below code. You should see errors less than `1e-8`. Use Device as 'cuda' if you have access to GPU.

# %%
from fully_connected_networks import ReLU

cs6476.utils.reset_seed(903322690)
x = torch.randn(10, 10, dtype=torch.float64,device='cpu')
dout = torch.randn(*x.shape, dtype=torch.float64,device='cpu')

dx_num = cs6476.grad.compute_numeric_gradient(lambda x: ReLU.forward(x)[0], x, dout)

_, cache = ReLU.forward(x)
dx = ReLU.backward(dout, cache)

print('Testing ReLU.backward function:')
print('dx error: ', cs6476.grad.rel_error(dx_num, dx))
# Out:
# Testing ReLU.backward function:
# dx error:  4.076265263542414e-10

# %% [markdown]
# # "Convinience" layers
# Linear layers are frequently followed by a ReLU nonlinearity. To make these common patterns easy, we define a convenience layer. Combination forward and backward linear layers in conjunction with ReLU is given in code `Linear_ReLU`. Run the following to verify you implementations in conjunction. You should see errors less than `1e-8`.Use Device as 'cuda' if you have access to GPU.

# %%
from fully_connected_networks import Linear_ReLU

cs6476.utils.reset_seed(903322690)
x = torch.randn(2, 3, 4, dtype=torch.float64,device='cpu')
w = torch.randn(12, 10, dtype=torch.float64,device='cpu')
b = torch.randn(10, dtype=torch.float64,device='cpu')
dout = torch.randn(2, 10, dtype=torch.float64,device='cpu')

out, cache = Linear_ReLU.forward(x, w, b)
dx, dw, db = Linear_ReLU.backward(dout, cache)

dx_num = cs6476.grad.compute_numeric_gradient(lambda x: Linear_ReLU.forward(x, w, b)[0], x, dout)
dw_num = cs6476.grad.compute_numeric_gradient(lambda w: Linear_ReLU.forward(x, w, b)[0], w, dout)
db_num = cs6476.grad.compute_numeric_gradient(lambda b: Linear_ReLU.forward(x, w, b)[0], b, dout)

# Relative error should be around e-8 or less
print('Testing Linear_ReLU.forward and Linear_ReLU.backward:')
print('dx error: ', cs6476.grad.rel_error(dx_num, dx))
print('dw error: ', cs6476.grad.rel_error(dw_num, dw))
print('db error: ', cs6476.grad.rel_error(db_num, db))
# Out:
# Testing Linear_ReLU.forward and Linear_ReLU.backward:
# dx error:  4.519924704408903e-10
# dw error:  3.4616347471466947e-10
# db error:  2.2316272957733857e-10

# %% [markdown]
# # Loss layers: Softmax
# we have provided the softmax loss function to you for free in `helper_functions.py`.You cn verify your code flow so far by running the script below. You should see errors less than `1e-6` for softmax_loss.

# %%
from a2_helper import softmax_loss

cs6476.utils.reset_seed(903322690)
num_classes, num_inputs = 10, 50
x = 0.001 * torch.randn(num_inputs, num_classes, dtype=torch.float64,device='cpu')
y = torch.randint(num_classes, size=(num_inputs,), dtype=torch.int64,device='cpu')

dx_num = cs6476.grad.compute_numeric_gradient(lambda x: softmax_loss(x, y)[0], x)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss.item())
print('dx error: ', cs6476.grad.rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.302442681602023
# dx error:  7.01102639621429e-08

# %% [markdown]
# # Two-layer network
# Utilize you modular implementation to build a Two-layer network. Complete the implementation in the `TwoLayerNet` class. Test your implementation using the following code.
# Note: Backpropogation/Backward pass has already been implemented for your convinience.
# Refer to the following formula when adding regularization term to the loss.

# %% [markdown]
# $regularized\_loss = loss + \lambda \sum_{j}w_j^2$

# %%
from fully_connected_networks import TwoLayerNet
from a2_helper import softmax_loss

cs6476.utils.reset_seed(903322690)
N, D, H, C = 3, 5, 50, 7
X = torch.randn(N, D, dtype=torch.float64,device='cpu')
y = torch.randint(C, size=(N,), dtype=torch.int64,device='cpu')

std = 1e-3
model = TwoLayerNet(
          input_dim=D,
          hidden_dim=H,
          num_classes=C,
          weight_scale=std,
          dtype=torch.float64,
          device='cuda'
        )

print('Testing initialization ... ')
W1_std = torch.abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = torch.abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert torch.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert torch.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = torch.linspace(-0.7, 0.3, steps=D * H, dtype=torch.float64,device='cpu').reshape(D, H)
model.params['b1'] = torch.linspace(-0.1, 0.9, steps=H, dtype=torch.float64,device='cpu')
model.params['W2'] = torch.linspace(-0.3, 0.4, steps=H * C, dtype=torch.float64,device='cpu').reshape(H, C)
model.params['b2'] = torch.linspace(-0.9, 0.1, steps=C, dtype=torch.float64,device='cpu')
X = torch.linspace(-5.5, 4.5, steps=N * D, dtype=torch.float64,device='cpu').reshape(D, N).t()
scores = model.loss(X)
correct_scores = torch.tensor(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]],
    dtype=torch.float64,device='cpu')
scores_diff = torch.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = torch.tensor([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 49.719461034881775
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-6 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = cs6476.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, cs6476.grad.rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.99e-07
# W2 relative error: 1.49e-09
# b1 relative error: 9.91e-07
# b2 relative error: 4.21e-09
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.79e-08
# W2 relative error: 8.33e-09
# b1 relative error: 6.27e-07
# b2 relative error: 2.30e-08

# %% [markdown]
# # Solver
# We have split the logic for training models into a separate class. We use a `Solver` instance to train a `TwoLayerNet` that achieves at least `50%` accuracy on the validation set. For the two layer net we use a specific instance of the function. Use the helper function to get a general idea on how to use `Solver`

# %%
print(help(Solver))

# %%
from fully_connected_networks import create_solver_instance

cs6476.utils.reset_seed(903322690)

# Create a solver instance that achieves 50% performance on the validation set
solver = create_solver_instance(data_dict=data_dict, dtype=torch.float64,device='cpu')
solver.train()
# Out:
# (Time 0.03 sec; Iteration 1 / 40000) loss: 2.302571
# cpu
# (Epoch 0 / 100) train acc: 0.090000; val_acc: 0.102500
# (Time 0.79 sec; Iteration 11 / 40000) loss: 2.302499
# (Time 1.02 sec; Iteration 21 / 40000) loss: 2.302621
# (Time 1.29 sec; Iteration 31 / 40000) loss: 2.302325
# (Time 1.54 sec; Iteration 41 / 40000) loss: 2.302425
# (Time 1.80 sec; Iteration 51 / 40000) loss: 2.302689
# (Time 2.05 sec; Iteration 61 / 40000) loss: 2.302582
# (Time 2.31 sec; Iteration 71 / 40000) loss: 2.302749
# (Time 2.57 sec; Iteration 81 / 40000) loss: 2.302171
# (Time 2.82 sec; Iteration 91 / 40000) loss: 2.302721
# (Time 3.06 sec; Iteration 101 / 40000) loss: 2.302441
# (Time 3.37 sec; Iteration 111 / 40000) loss: 2.302026
# (Time 3.78 sec; Iteration 121 / 40000) loss: 2.302256
# (Time 4.25 sec; Iteration 131 / 40000) loss: 2.302051
# (Time 5.11 sec; Iteration 141 / 40000) loss: 2.302785
# (Time 6.53 sec; Iteration 151 / 40000) loss: 2.303328
# (Time 7.30 sec; Iteration 161 / 40000) loss: 2.302883
# (Time 8.24 sec; Iteration 171 / 40000) loss: 2.303177
# (Time 9.42 sec; Iteration 181 / 40000) loss: 2.302377
# (Time 9.98 sec; Iteration 191 / 40000) loss: 2.301906
# (Time 10.52 sec; Iteration 201 / 40000) loss: 2.301880
# (Time 11.53 sec; Iteration 211 / 40000) loss: 2.301769
# (Time 11.91 sec; Iteration 221 / 40000) loss: 2.301943
# (Time 12.17 sec; Iteration 231 / 40000) loss: 2.302063
# (Time 12.40 sec; Iteration 241 / 40000) loss: 2.302126
# (Time 12.65 sec; Iteration 251 / 40000) loss: 2.301310
# (Time 12.91 sec; Iteration 261 / 40000) loss: 2.301432
# (Time 13.15 sec; Iteration 271 / 40000) loss: 2.301401
# (Time 13.41 sec; Iteration 281 / 40000) loss: 2.301736
# (Time 13.66 sec; Iteration 291 / 40000) loss: 2.300375
# (Time 13.92 sec; Iteration 301 / 40000) loss: 2.301583
# (Time 14.16 sec; Iteration 311 / 40000) loss: 2.301085
# (Time 14.41 sec; Iteration 321 / 40000) loss: 2.300102
# (Time 14.66 sec; Iteration 331 / 40000) loss: 2.300667
# (Time 14.92 sec; Iteration 341 / 40000) loss: 2.300385
# (Time 15.18 sec; Iteration 351 / 40000) loss: 2.298932
# (Time 15.42 sec; Iteration 361 / 40000) loss: 2.300052
# (Time 15.67 sec; Iteration 371 / 40000) loss: 2.298439
# (Time 15.93 sec; Iteration 381 / 40000) loss: 2.296666
# (Time 16.16 sec; Iteration 391 / 40000) loss: 2.299176
# cpu
# (Epoch 1 / 100) train acc: 0.158000; val_acc: 0.163500
# (Time 17.02 sec; Iteration 401 / 40000) loss: 2.296656
# (Time 17.45 sec; Iteration 411 / 40000) loss: 2.295890
# (Time 18.00 sec; Iteration 421 / 40000) loss: 2.294940
# (Time 18.31 sec; Iteration 431 / 40000) loss: 2.294987
# (Time 18.55 sec; Iteration 441 / 40000) loss: 2.293820
# (Time 18.81 sec; Iteration 451 / 40000) loss: 2.296892
# (Time 19.06 sec; Iteration 461 / 40000) loss: 2.286168
# (Time 19.38 sec; Iteration 471 / 40000) loss: 2.287672
# (Time 19.72 sec; Iteration 481 / 40000) loss: 2.294816
# (Time 20.08 sec; Iteration 491 / 40000) loss: 2.289943
# (Time 20.42 sec; Iteration 501 / 40000) loss: 2.282305
# (Time 20.76 sec; Iteration 511 / 40000) loss: 2.284596
# (Time 21.10 sec; Iteration 521 / 40000) loss: 2.282656
# (Time 21.45 sec; Iteration 531 / 40000) loss: 2.286477
# (Time 21.79 sec; Iteration 541 / 40000) loss: 2.283248
# (Time 22.14 sec; Iteration 551 / 40000) loss: 2.271406
# (Time 22.49 sec; Iteration 561 / 40000) loss: 2.282433
# (Time 22.83 sec; Iteration 571 / 40000) loss: 2.288516
# (Time 23.18 sec; Iteration 581 / 40000) loss: 2.284533
# (Time 23.52 sec; Iteration 591 / 40000) loss: 2.276322
# (Time 23.81 sec; Iteration 601 / 40000) loss: 2.274790
# (Time 24.06 sec; Iteration 611 / 40000) loss: 2.249728
# (Time 24.33 sec; Iteration 621 / 40000) loss: 2.265189
# (Time 24.58 sec; Iteration 631 / 40000) loss: 2.277743
# (Time 24.83 sec; Iteration 641 / 40000) loss: 2.246603
# (Time 25.08 sec; Iteration 651 / 40000) loss: 2.250557
# (Time 25.33 sec; Iteration 661 / 40000) loss: 2.225868
# (Time 25.57 sec; Iteration 671 / 40000) loss: 2.252022
# (Time 25.82 sec; Iteration 681 / 40000) loss: 2.244196
# (Time 26.07 sec; Iteration 691 / 40000) loss: 2.239225
# (Time 26.32 sec; Iteration 701 / 40000) loss: 2.212897
# (Time 26.57 sec; Iteration 711 / 40000) loss: 2.219414
# (Time 26.81 sec; Iteration 721 / 40000) loss: 2.228486
# (Time 27.05 sec; Iteration 731 / 40000) loss: 2.213720
# (Time 27.29 sec; Iteration 741 / 40000) loss: 2.257670
# (Time 27.54 sec; Iteration 751 / 40000) loss: 2.215568
# (Time 27.78 sec; Iteration 761 / 40000) loss: 2.213810
# (Time 28.02 sec; Iteration 771 / 40000) loss: 2.234687
# (Time 28.26 sec; Iteration 781 / 40000) loss: 2.198635
# (Time 28.51 sec; Iteration 791 / 40000) loss: 2.230417
# cpu
# (Epoch 2 / 100) train acc: 0.153000; val_acc: 0.171800
# (Time 29.37 sec; Iteration 801 / 40000) loss: 2.216150
# (Time 29.65 sec; Iteration 811 / 40000) loss: 2.229484
# (Time 29.92 sec; Iteration 821 / 40000) loss: 2.223174
# (Time 30.20 sec; Iteration 831 / 40000) loss: 2.195756
# (Time 30.46 sec; Iteration 841 / 40000) loss: 2.151066
# (Time 30.72 sec; Iteration 851 / 40000) loss: 2.191037
# (Time 30.98 sec; Iteration 861 / 40000) loss: 2.118017
# (Time 31.23 sec; Iteration 871 / 40000) loss: 2.215260
# (Time 31.48 sec; Iteration 881 / 40000) loss: 2.152702
# (Time 31.71 sec; Iteration 891 / 40000) loss: 2.241699
# (Time 31.91 sec; Iteration 901 / 40000) loss: 2.198500
# (Time 32.12 sec; Iteration 911 / 40000) loss: 2.154489
# (Time 32.33 sec; Iteration 921 / 40000) loss: 2.214462
# (Time 32.54 sec; Iteration 931 / 40000) loss: 2.184749
# (Time 32.77 sec; Iteration 941 / 40000) loss: 2.168868
# (Time 33.02 sec; Iteration 951 / 40000) loss: 2.181485
# (Time 33.26 sec; Iteration 961 / 40000) loss: 2.186041
# (Time 33.51 sec; Iteration 971 / 40000) loss: 2.171173
# (Time 33.83 sec; Iteration 981 / 40000) loss: 2.184499
# (Time 34.16 sec; Iteration 991 / 40000) loss: 2.125326
# (Time 34.49 sec; Iteration 1001 / 40000) loss: 2.220112
# (Time 34.83 sec; Iteration 1011 / 40000) loss: 2.186186
# (Time 35.18 sec; Iteration 1021 / 40000) loss: 2.130175
# (Time 35.52 sec; Iteration 1031 / 40000) loss: 2.196540
# (Time 35.87 sec; Iteration 1041 / 40000) loss: 2.079156
# (Time 36.21 sec; Iteration 1051 / 40000) loss: 2.069715
# (Time 36.55 sec; Iteration 1061 / 40000) loss: 2.149938
# (Time 36.92 sec; Iteration 1071 / 40000) loss: 2.093440
# (Time 37.26 sec; Iteration 1081 / 40000) loss: 2.085535
# (Time 37.60 sec; Iteration 1091 / 40000) loss: 2.191230
# (Time 37.93 sec; Iteration 1101 / 40000) loss: 2.155001
# (Time 38.17 sec; Iteration 1111 / 40000) loss: 2.191527
# (Time 38.40 sec; Iteration 1121 / 40000) loss: 2.094692
# (Time 38.64 sec; Iteration 1131 / 40000) loss: 2.092924
# (Time 38.89 sec; Iteration 1141 / 40000) loss: 2.139735
# (Time 39.14 sec; Iteration 1151 / 40000) loss: 2.160751
# (Time 39.39 sec; Iteration 1161 / 40000) loss: 2.041537
# (Time 39.63 sec; Iteration 1171 / 40000) loss: 2.153763
# (Time 39.89 sec; Iteration 1181 / 40000) loss: 2.095661
# (Time 40.14 sec; Iteration 1191 / 40000) loss: 2.087294
# cpu
# (Epoch 3 / 100) train acc: 0.219000; val_acc: 0.238600
# (Time 40.98 sec; Iteration 1201 / 40000) loss: 2.050719
# (Time 41.22 sec; Iteration 1211 / 40000) loss: 2.089754
# (Time 41.47 sec; Iteration 1221 / 40000) loss: 2.041894
# (Time 41.72 sec; Iteration 1231 / 40000) loss: 2.142757
# (Time 41.95 sec; Iteration 1241 / 40000) loss: 2.101933
# (Time 42.16 sec; Iteration 1251 / 40000) loss: 2.110972
# (Time 42.36 sec; Iteration 1261 / 40000) loss: 2.096310
# (Time 42.57 sec; Iteration 1271 / 40000) loss: 2.132251
# (Time 42.77 sec; Iteration 1281 / 40000) loss: 2.091114
# (Time 43.00 sec; Iteration 1291 / 40000) loss: 2.122337
# (Time 43.25 sec; Iteration 1301 / 40000) loss: 2.039404
# (Time 43.49 sec; Iteration 1311 / 40000) loss: 2.076104
# (Time 43.75 sec; Iteration 1321 / 40000) loss: 2.114035
# (Time 44.00 sec; Iteration 1331 / 40000) loss: 2.108762
# (Time 44.25 sec; Iteration 1341 / 40000) loss: 2.114174
# (Time 44.49 sec; Iteration 1351 / 40000) loss: 2.082266
# (Time 44.74 sec; Iteration 1361 / 40000) loss: 2.056293
# (Time 45.00 sec; Iteration 1371 / 40000) loss: 2.099604
# (Time 45.26 sec; Iteration 1381 / 40000) loss: 1.974681
# (Time 45.50 sec; Iteration 1391 / 40000) loss: 2.031607
# (Time 45.74 sec; Iteration 1401 / 40000) loss: 2.081218
# (Time 45.99 sec; Iteration 1411 / 40000) loss: 2.055019
# (Time 46.24 sec; Iteration 1421 / 40000) loss: 2.031647
# (Time 46.49 sec; Iteration 1431 / 40000) loss: 1.994240
# (Time 46.73 sec; Iteration 1441 / 40000) loss: 1.943499
# (Time 46.97 sec; Iteration 1451 / 40000) loss: 2.020985
# (Time 47.23 sec; Iteration 1461 / 40000) loss: 2.074514
# (Time 47.48 sec; Iteration 1471 / 40000) loss: 2.076835
# (Time 47.72 sec; Iteration 1481 / 40000) loss: 2.089865
# (Time 48.00 sec; Iteration 1491 / 40000) loss: 1.942042
# (Time 48.34 sec; Iteration 1501 / 40000) loss: 2.016826
# (Time 48.67 sec; Iteration 1511 / 40000) loss: 1.984142
# (Time 49.01 sec; Iteration 1521 / 40000) loss: 2.041037
# (Time 49.34 sec; Iteration 1531 / 40000) loss: 2.011247
# (Time 49.68 sec; Iteration 1541 / 40000) loss: 2.028659
# (Time 50.01 sec; Iteration 1551 / 40000) loss: 2.022362
# (Time 50.36 sec; Iteration 1561 / 40000) loss: 1.898543
# (Time 50.71 sec; Iteration 1571 / 40000) loss: 1.995493
# (Time 51.06 sec; Iteration 1581 / 40000) loss: 1.940560
# (Time 51.40 sec; Iteration 1591 / 40000) loss: 2.004560
# cpu
# (Epoch 4 / 100) train acc: 0.259000; val_acc: 0.256800
# (Time 52.50 sec; Iteration 1601 / 40000) loss: 1.963829
# (Time 52.75 sec; Iteration 1611 / 40000) loss: 2.037114
# (Time 53.00 sec; Iteration 1621 / 40000) loss: 2.072197
# (Time 53.24 sec; Iteration 1631 / 40000) loss: 1.974371
# (Time 53.50 sec; Iteration 1641 / 40000) loss: 2.051944
# (Time 53.74 sec; Iteration 1651 / 40000) loss: 1.922245
# (Time 54.00 sec; Iteration 1661 / 40000) loss: 1.885247
# (Time 54.24 sec; Iteration 1671 / 40000) loss: 2.042393
# (Time 54.47 sec; Iteration 1681 / 40000) loss: 2.071428
# (Time 54.73 sec; Iteration 1691 / 40000) loss: 1.994769
# (Time 54.97 sec; Iteration 1701 / 40000) loss: 2.031967
# (Time 55.22 sec; Iteration 1711 / 40000) loss: 2.105099
# (Time 55.45 sec; Iteration 1721 / 40000) loss: 2.045094
# (Time 55.71 sec; Iteration 1731 / 40000) loss: 2.056844
# (Time 55.95 sec; Iteration 1741 / 40000) loss: 1.956078
# (Time 56.21 sec; Iteration 1751 / 40000) loss: 2.054680
# (Time 56.46 sec; Iteration 1761 / 40000) loss: 1.844631
# (Time 56.74 sec; Iteration 1771 / 40000) loss: 1.990736
# (Time 56.99 sec; Iteration 1781 / 40000) loss: 1.940268
# (Time 57.24 sec; Iteration 1791 / 40000) loss: 2.098808
# (Time 57.49 sec; Iteration 1801 / 40000) loss: 1.994964
# (Time 57.77 sec; Iteration 1811 / 40000) loss: 2.076923
# (Time 58.02 sec; Iteration 1821 / 40000) loss: 1.890781
# (Time 58.27 sec; Iteration 1831 / 40000) loss: 2.032471
# (Time 58.51 sec; Iteration 1841 / 40000) loss: 1.984057
# (Time 58.77 sec; Iteration 1851 / 40000) loss: 1.976429
# (Time 59.01 sec; Iteration 1861 / 40000) loss: 1.998615
# (Time 59.26 sec; Iteration 1871 / 40000) loss: 2.034945
# (Time 59.50 sec; Iteration 1881 / 40000) loss: 1.953748
# (Time 59.75 sec; Iteration 1891 / 40000) loss: 1.988174
# (Time 60.00 sec; Iteration 1901 / 40000) loss: 1.800860
# (Time 60.24 sec; Iteration 1911 / 40000) loss: 2.101024
# (Time 60.48 sec; Iteration 1921 / 40000) loss: 1.887099
# (Time 60.74 sec; Iteration 1931 / 40000) loss: 2.013760
# (Time 60.99 sec; Iteration 1941 / 40000) loss: 2.069064
# (Time 61.24 sec; Iteration 1951 / 40000) loss: 1.949830
# (Time 61.49 sec; Iteration 1961 / 40000) loss: 2.029190
# (Time 61.74 sec; Iteration 1971 / 40000) loss: 2.012125
# (Time 61.99 sec; Iteration 1981 / 40000) loss: 2.084068
# (Time 62.23 sec; Iteration 1991 / 40000) loss: 1.876557
# cpu
# (Epoch 5 / 100) train acc: 0.287000; val_acc: 0.278100
# (Time 63.47 sec; Iteration 2001 / 40000) loss: 2.014662
# (Time 63.81 sec; Iteration 2011 / 40000) loss: 1.891423
# (Time 64.16 sec; Iteration 2021 / 40000) loss: 1.990850
# (Time 64.49 sec; Iteration 2031 / 40000) loss: 1.844392
# (Time 64.83 sec; Iteration 2041 / 40000) loss: 1.979208
# (Time 65.18 sec; Iteration 2051 / 40000) loss: 2.042404
# (Time 65.52 sec; Iteration 2061 / 40000) loss: 1.955972
# (Time 65.85 sec; Iteration 2071 / 40000) loss: 1.941597
# (Time 66.21 sec; Iteration 2081 / 40000) loss: 2.015963
# (Time 66.54 sec; Iteration 2091 / 40000) loss: 1.896412
# (Time 66.79 sec; Iteration 2101 / 40000) loss: 1.975708
# (Time 67.06 sec; Iteration 2111 / 40000) loss: 1.978485
# (Time 67.30 sec; Iteration 2121 / 40000) loss: 1.929677
# (Time 67.54 sec; Iteration 2131 / 40000) loss: 1.849676
# (Time 67.78 sec; Iteration 2141 / 40000) loss: 2.022669
# (Time 68.03 sec; Iteration 2151 / 40000) loss: 1.993804
# (Time 68.28 sec; Iteration 2161 / 40000) loss: 1.882102
# (Time 68.52 sec; Iteration 2171 / 40000) loss: 1.869411
# (Time 68.76 sec; Iteration 2181 / 40000) loss: 1.969878
# (Time 69.00 sec; Iteration 2191 / 40000) loss: 2.000156
# (Time 69.26 sec; Iteration 2201 / 40000) loss: 1.998125
# (Time 69.51 sec; Iteration 2211 / 40000) loss: 1.932760
# (Time 69.76 sec; Iteration 2221 / 40000) loss: 2.096418
# (Time 70.00 sec; Iteration 2231 / 40000) loss: 1.988951
# (Time 70.24 sec; Iteration 2241 / 40000) loss: 1.870070
# (Time 70.48 sec; Iteration 2251 / 40000) loss: 1.918608
# (Time 70.73 sec; Iteration 2261 / 40000) loss: 1.966969
# (Time 70.97 sec; Iteration 2271 / 40000) loss: 1.864327
# (Time 71.22 sec; Iteration 2281 / 40000) loss: 1.794264
# (Time 71.45 sec; Iteration 2291 / 40000) loss: 1.934216
# (Time 71.71 sec; Iteration 2301 / 40000) loss: 1.926059
# (Time 71.95 sec; Iteration 2311 / 40000) loss: 1.856739
# (Time 72.19 sec; Iteration 2321 / 40000) loss: 1.977812
# (Time 72.44 sec; Iteration 2331 / 40000) loss: 1.989079
# (Time 72.69 sec; Iteration 2341 / 40000) loss: 1.883787
# (Time 72.93 sec; Iteration 2351 / 40000) loss: 1.984101
# (Time 73.18 sec; Iteration 2361 / 40000) loss: 1.968344
# (Time 73.44 sec; Iteration 2371 / 40000) loss: 1.883485
# (Time 73.68 sec; Iteration 2381 / 40000) loss: 1.862105
# (Time 73.93 sec; Iteration 2391 / 40000) loss: 2.075307
# cpu
# (Epoch 6 / 100) train acc: 0.311000; val_acc: 0.308200
# (Time 74.78 sec; Iteration 2401 / 40000) loss: 1.903192
# (Time 75.04 sec; Iteration 2411 / 40000) loss: 1.863073
# (Time 75.29 sec; Iteration 2421 / 40000) loss: 1.858792
# (Time 75.55 sec; Iteration 2431 / 40000) loss: 1.879447
# (Time 75.79 sec; Iteration 2441 / 40000) loss: 1.918847
# (Time 76.04 sec; Iteration 2451 / 40000) loss: 1.880144
# (Time 76.28 sec; Iteration 2461 / 40000) loss: 1.868408
# (Time 76.53 sec; Iteration 2471 / 40000) loss: 1.898286
# (Time 76.88 sec; Iteration 2481 / 40000) loss: 1.944868
# (Time 77.23 sec; Iteration 2491 / 40000) loss: 1.793358
# (Time 77.58 sec; Iteration 2501 / 40000) loss: 1.853134
# (Time 77.92 sec; Iteration 2511 / 40000) loss: 1.920343
# (Time 78.25 sec; Iteration 2521 / 40000) loss: 1.975147
# (Time 78.61 sec; Iteration 2531 / 40000) loss: 1.926524
# (Time 78.95 sec; Iteration 2541 / 40000) loss: 1.911432
# (Time 79.29 sec; Iteration 2551 / 40000) loss: 1.816693
# (Time 79.62 sec; Iteration 2561 / 40000) loss: 1.944302
# (Time 79.96 sec; Iteration 2571 / 40000) loss: 1.827395
# (Time 80.30 sec; Iteration 2581 / 40000) loss: 1.791037
# (Time 80.64 sec; Iteration 2591 / 40000) loss: 1.947987
# (Time 80.95 sec; Iteration 2601 / 40000) loss: 1.917040
# (Time 81.19 sec; Iteration 2611 / 40000) loss: 1.850794
# (Time 81.44 sec; Iteration 2621 / 40000) loss: 2.005888
# (Time 81.70 sec; Iteration 2631 / 40000) loss: 1.930857
# (Time 81.95 sec; Iteration 2641 / 40000) loss: 1.872339
# (Time 82.19 sec; Iteration 2651 / 40000) loss: 1.954528
# (Time 82.44 sec; Iteration 2661 / 40000) loss: 1.957454
# (Time 82.69 sec; Iteration 2671 / 40000) loss: 1.869119
# (Time 82.95 sec; Iteration 2681 / 40000) loss: 1.971883
# (Time 83.19 sec; Iteration 2691 / 40000) loss: 1.862534
# (Time 83.44 sec; Iteration 2701 / 40000) loss: 1.874456
# (Time 83.69 sec; Iteration 2711 / 40000) loss: 2.006141
# (Time 83.93 sec; Iteration 2721 / 40000) loss: 1.786731
# (Time 84.14 sec; Iteration 2731 / 40000) loss: 2.046065
# (Time 84.34 sec; Iteration 2741 / 40000) loss: 1.861640
# (Time 84.56 sec; Iteration 2751 / 40000) loss: 1.795248
# (Time 84.76 sec; Iteration 2761 / 40000) loss: 1.945589
# (Time 84.99 sec; Iteration 2771 / 40000) loss: 2.018146
# (Time 85.19 sec; Iteration 2781 / 40000) loss: 1.900563
# (Time 85.39 sec; Iteration 2791 / 40000) loss: 1.875804
# cpu
# (Epoch 7 / 100) train acc: 0.302000; val_acc: 0.324700
# (Time 86.17 sec; Iteration 2801 / 40000) loss: 1.844322
# (Time 86.40 sec; Iteration 2811 / 40000) loss: 1.743804
# (Time 86.65 sec; Iteration 2821 / 40000) loss: 1.760912
# (Time 86.92 sec; Iteration 2831 / 40000) loss: 1.802544
# (Time 87.16 sec; Iteration 2841 / 40000) loss: 1.797666
# (Time 87.40 sec; Iteration 2851 / 40000) loss: 1.890060
# (Time 87.64 sec; Iteration 2861 / 40000) loss: 1.852976
# (Time 87.89 sec; Iteration 2871 / 40000) loss: 1.748849
# (Time 88.13 sec; Iteration 2881 / 40000) loss: 1.726198
# (Time 88.37 sec; Iteration 2891 / 40000) loss: 1.821989
# (Time 88.62 sec; Iteration 2901 / 40000) loss: 1.837699
# (Time 88.87 sec; Iteration 2911 / 40000) loss: 1.771235
# (Time 89.12 sec; Iteration 2921 / 40000) loss: 1.822285
# (Time 89.36 sec; Iteration 2931 / 40000) loss: 1.711355
# (Time 89.60 sec; Iteration 2941 / 40000) loss: 1.848920
# (Time 89.85 sec; Iteration 2951 / 40000) loss: 1.748093
# (Time 90.10 sec; Iteration 2961 / 40000) loss: 1.674101
# (Time 90.34 sec; Iteration 2971 / 40000) loss: 1.871971
# (Time 90.58 sec; Iteration 2981 / 40000) loss: 1.812262
# (Time 90.83 sec; Iteration 2991 / 40000) loss: 1.798388
# (Time 91.17 sec; Iteration 3001 / 40000) loss: 1.875243
# (Time 91.52 sec; Iteration 3011 / 40000) loss: 1.757292
# (Time 91.85 sec; Iteration 3021 / 40000) loss: 1.860230
# (Time 92.19 sec; Iteration 3031 / 40000) loss: 1.760144
# (Time 92.53 sec; Iteration 3041 / 40000) loss: 1.774321
# (Time 92.86 sec; Iteration 3051 / 40000) loss: 1.814708
# (Time 93.22 sec; Iteration 3061 / 40000) loss: 1.825822
# (Time 93.57 sec; Iteration 3071 / 40000) loss: 1.825867
# (Time 93.91 sec; Iteration 3081 / 40000) loss: 1.718530
# (Time 94.26 sec; Iteration 3091 / 40000) loss: 1.922574
# (Time 94.59 sec; Iteration 3101 / 40000) loss: 1.869553
# (Time 94.92 sec; Iteration 3111 / 40000) loss: 1.832843
# (Time 95.24 sec; Iteration 3121 / 40000) loss: 1.855900
# (Time 95.48 sec; Iteration 3131 / 40000) loss: 1.874651
# (Time 95.71 sec; Iteration 3141 / 40000) loss: 1.811440
# (Time 95.95 sec; Iteration 3151 / 40000) loss: 1.874551
# (Time 96.19 sec; Iteration 3161 / 40000) loss: 1.770316
# (Time 96.43 sec; Iteration 3171 / 40000) loss: 1.832437
# (Time 96.67 sec; Iteration 3181 / 40000) loss: 1.784125
# (Time 96.91 sec; Iteration 3191 / 40000) loss: 1.849021
# cpu
# (Epoch 8 / 100) train acc: 0.379000; val_acc: 0.339300
# (Time 97.74 sec; Iteration 3201 / 40000) loss: 1.836508
# (Time 97.98 sec; Iteration 3211 / 40000) loss: 1.962680
# (Time 98.23 sec; Iteration 3221 / 40000) loss: 1.866865
# (Time 98.48 sec; Iteration 3231 / 40000) loss: 1.823036
# (Time 98.72 sec; Iteration 3241 / 40000) loss: 1.814078
# (Time 98.97 sec; Iteration 3251 / 40000) loss: 1.886040
# (Time 99.20 sec; Iteration 3261 / 40000) loss: 1.797121
# (Time 99.46 sec; Iteration 3271 / 40000) loss: 1.816744
# (Time 99.71 sec; Iteration 3281 / 40000) loss: 1.863376
# (Time 99.96 sec; Iteration 3291 / 40000) loss: 1.758973
# (Time 100.21 sec; Iteration 3301 / 40000) loss: 1.783119
# (Time 100.46 sec; Iteration 3311 / 40000) loss: 1.746449
# (Time 100.71 sec; Iteration 3321 / 40000) loss: 1.612029
# (Time 100.94 sec; Iteration 3331 / 40000) loss: 1.849207
# (Time 101.18 sec; Iteration 3341 / 40000) loss: 1.780988
# (Time 101.42 sec; Iteration 3351 / 40000) loss: 1.746555
# (Time 101.68 sec; Iteration 3361 / 40000) loss: 1.865724
# (Time 101.92 sec; Iteration 3371 / 40000) loss: 1.760214
# (Time 102.16 sec; Iteration 3381 / 40000) loss: 1.833142
# (Time 102.40 sec; Iteration 3391 / 40000) loss: 1.540112
# (Time 102.65 sec; Iteration 3401 / 40000) loss: 1.913522
# (Time 102.90 sec; Iteration 3411 / 40000) loss: 1.896569
# (Time 103.15 sec; Iteration 3421 / 40000) loss: 1.800820
# (Time 103.40 sec; Iteration 3431 / 40000) loss: 1.758394
# (Time 103.65 sec; Iteration 3441 / 40000) loss: 1.851380
# (Time 103.91 sec; Iteration 3451 / 40000) loss: 1.921415
# (Time 104.15 sec; Iteration 3461 / 40000) loss: 1.833348
# (Time 104.40 sec; Iteration 3471 / 40000) loss: 1.787903
# (Time 104.66 sec; Iteration 3481 / 40000) loss: 1.736164
# (Time 104.92 sec; Iteration 3491 / 40000) loss: 1.822490
# (Time 105.17 sec; Iteration 3501 / 40000) loss: 1.894760
# (Time 105.50 sec; Iteration 3511 / 40000) loss: 1.738748
# (Time 105.87 sec; Iteration 3521 / 40000) loss: 1.788538
# (Time 106.20 sec; Iteration 3531 / 40000) loss: 1.766978
# (Time 106.54 sec; Iteration 3541 / 40000) loss: 1.675573
# (Time 106.89 sec; Iteration 3551 / 40000) loss: 1.762537
# (Time 107.23 sec; Iteration 3561 / 40000) loss: 1.746017
# (Time 107.56 sec; Iteration 3571 / 40000) loss: 1.636104
# (Time 107.90 sec; Iteration 3581 / 40000) loss: 1.674117
# (Time 108.24 sec; Iteration 3591 / 40000) loss: 1.767192
# cpu
# (Epoch 9 / 100) train acc: 0.362000; val_acc: 0.353900
# (Time 109.47 sec; Iteration 3601 / 40000) loss: 1.875830
# (Time 109.71 sec; Iteration 3611 / 40000) loss: 1.756322
# (Time 109.97 sec; Iteration 3621 / 40000) loss: 1.966531
# (Time 110.21 sec; Iteration 3631 / 40000) loss: 1.799932
# (Time 110.45 sec; Iteration 3641 / 40000) loss: 1.863166
# (Time 110.70 sec; Iteration 3651 / 40000) loss: 1.602640
# (Time 110.95 sec; Iteration 3661 / 40000) loss: 1.815323
# (Time 111.21 sec; Iteration 3671 / 40000) loss: 1.850447
# (Time 111.45 sec; Iteration 3681 / 40000) loss: 1.824452
# (Time 111.70 sec; Iteration 3691 / 40000) loss: 1.641917
# (Time 111.95 sec; Iteration 3701 / 40000) loss: 1.992777
# (Time 112.21 sec; Iteration 3711 / 40000) loss: 1.718930
# (Time 112.45 sec; Iteration 3721 / 40000) loss: 1.863013
# (Time 112.69 sec; Iteration 3731 / 40000) loss: 1.885070
# (Time 112.94 sec; Iteration 3741 / 40000) loss: 1.669297
# (Time 113.20 sec; Iteration 3751 / 40000) loss: 1.890519
# (Time 113.45 sec; Iteration 3761 / 40000) loss: 1.829490
# (Time 113.70 sec; Iteration 3771 / 40000) loss: 1.780693
# (Time 113.95 sec; Iteration 3781 / 40000) loss: 1.934842
# (Time 114.20 sec; Iteration 3791 / 40000) loss: 1.744160
# (Time 114.44 sec; Iteration 3801 / 40000) loss: 1.685184
# (Time 114.69 sec; Iteration 3811 / 40000) loss: 1.726915
# (Time 114.93 sec; Iteration 3821 / 40000) loss: 1.777861
# (Time 115.20 sec; Iteration 3831 / 40000) loss: 1.621177
# (Time 115.44 sec; Iteration 3841 / 40000) loss: 1.825056
# (Time 115.69 sec; Iteration 3851 / 40000) loss: 1.900487
# (Time 115.93 sec; Iteration 3861 / 40000) loss: 1.791745
# (Time 116.18 sec; Iteration 3871 / 40000) loss: 1.721190
# (Time 116.42 sec; Iteration 3881 / 40000) loss: 1.857891
# (Time 116.97 sec; Iteration 3891 / 40000) loss: 1.811495
# (Time 117.25 sec; Iteration 3901 / 40000) loss: 1.602236
# (Time 117.48 sec; Iteration 3911 / 40000) loss: 1.793525
# (Time 117.72 sec; Iteration 3921 / 40000) loss: 1.888784
# (Time 117.96 sec; Iteration 3931 / 40000) loss: 1.767648
# (Time 118.21 sec; Iteration 3941 / 40000) loss: 1.807973
# (Time 118.45 sec; Iteration 3951 / 40000) loss: 1.698623
# (Time 118.70 sec; Iteration 3961 / 40000) loss: 1.864478
# (Time 118.95 sec; Iteration 3971 / 40000) loss: 1.839864
# (Time 119.20 sec; Iteration 3981 / 40000) loss: 1.812242
# (Time 119.45 sec; Iteration 3991 / 40000) loss: 1.790006
# cpu
# (Epoch 10 / 100) train acc: 0.353000; val_acc: 0.363200
# (Time 120.68 sec; Iteration 4001 / 40000) loss: 1.812696
# (Time 121.04 sec; Iteration 4011 / 40000) loss: 1.765390
# (Time 121.38 sec; Iteration 4021 / 40000) loss: 1.830900
# (Time 121.72 sec; Iteration 4031 / 40000) loss: 1.916469
# (Time 122.06 sec; Iteration 4041 / 40000) loss: 1.676959
# (Time 122.42 sec; Iteration 4051 / 40000) loss: 1.755676
# (Time 122.77 sec; Iteration 4061 / 40000) loss: 1.787985
# (Time 123.11 sec; Iteration 4071 / 40000) loss: 1.805287
# (Time 123.46 sec; Iteration 4081 / 40000) loss: 1.686995
# (Time 123.78 sec; Iteration 4091 / 40000) loss: 1.756798
# (Time 124.03 sec; Iteration 4101 / 40000) loss: 1.673788
# (Time 124.28 sec; Iteration 4111 / 40000) loss: 1.708480
# (Time 124.53 sec; Iteration 4121 / 40000) loss: 1.775106
# (Time 124.78 sec; Iteration 4131 / 40000) loss: 1.680020
# (Time 125.03 sec; Iteration 4141 / 40000) loss: 1.758561
# (Time 125.27 sec; Iteration 4151 / 40000) loss: 1.807573
# (Time 125.53 sec; Iteration 4161 / 40000) loss: 1.666397
# (Time 125.77 sec; Iteration 4171 / 40000) loss: 1.980446
# (Time 126.01 sec; Iteration 4181 / 40000) loss: 1.701929
# (Time 126.25 sec; Iteration 4191 / 40000) loss: 1.690184
# (Time 126.48 sec; Iteration 4201 / 40000) loss: 1.746099
# (Time 126.73 sec; Iteration 4211 / 40000) loss: 1.712101
# (Time 126.98 sec; Iteration 4221 / 40000) loss: 1.685277
# (Time 127.21 sec; Iteration 4231 / 40000) loss: 1.759741
# (Time 127.45 sec; Iteration 4241 / 40000) loss: 1.729611
# (Time 127.72 sec; Iteration 4251 / 40000) loss: 1.823643
# (Time 127.97 sec; Iteration 4261 / 40000) loss: 1.885146
# (Time 128.21 sec; Iteration 4271 / 40000) loss: 1.736047
# (Time 128.45 sec; Iteration 4281 / 40000) loss: 1.627436
# (Time 128.70 sec; Iteration 4291 / 40000) loss: 1.725209
# (Time 128.95 sec; Iteration 4301 / 40000) loss: 1.785341
# (Time 129.20 sec; Iteration 4311 / 40000) loss: 1.705037
# (Time 129.44 sec; Iteration 4321 / 40000) loss: 1.782310
# (Time 129.70 sec; Iteration 4331 / 40000) loss: 1.729727
# (Time 129.94 sec; Iteration 4341 / 40000) loss: 1.776444
# (Time 130.19 sec; Iteration 4351 / 40000) loss: 1.773258
# (Time 130.43 sec; Iteration 4361 / 40000) loss: 1.742261
# (Time 130.68 sec; Iteration 4371 / 40000) loss: 1.783558
# (Time 130.93 sec; Iteration 4381 / 40000) loss: 1.655882
# (Time 131.17 sec; Iteration 4391 / 40000) loss: 1.825145
# cpu
# (Epoch 11 / 100) train acc: 0.364000; val_acc: 0.369800
# (Time 132.01 sec; Iteration 4401 / 40000) loss: 1.660650
# (Time 132.25 sec; Iteration 4411 / 40000) loss: 1.723203
# (Time 132.49 sec; Iteration 4421 / 40000) loss: 1.659810
# (Time 132.74 sec; Iteration 4431 / 40000) loss: 1.728184
# (Time 132.99 sec; Iteration 4441 / 40000) loss: 1.886734
# (Time 133.24 sec; Iteration 4451 / 40000) loss: 1.789883
# (Time 133.48 sec; Iteration 4461 / 40000) loss: 1.778713
# (Time 133.75 sec; Iteration 4471 / 40000) loss: 1.663771
# (Time 134.10 sec; Iteration 4481 / 40000) loss: 1.745001
# (Time 134.43 sec; Iteration 4491 / 40000) loss: 1.746150
# (Time 134.75 sec; Iteration 4501 / 40000) loss: 1.600285
# (Time 135.12 sec; Iteration 4511 / 40000) loss: 1.685132
# (Time 135.45 sec; Iteration 4521 / 40000) loss: 1.999482
# (Time 135.80 sec; Iteration 4531 / 40000) loss: 1.637050
# (Time 136.15 sec; Iteration 4541 / 40000) loss: 1.704358
# (Time 136.50 sec; Iteration 4551 / 40000) loss: 1.571456
# (Time 136.84 sec; Iteration 4561 / 40000) loss: 1.604177
# (Time 137.19 sec; Iteration 4571 / 40000) loss: 1.750153
# (Time 137.53 sec; Iteration 4581 / 40000) loss: 1.702721
# (Time 137.88 sec; Iteration 4591 / 40000) loss: 1.620799
# (Time 138.19 sec; Iteration 4601 / 40000) loss: 1.652457
# (Time 138.43 sec; Iteration 4611 / 40000) loss: 1.592516
# (Time 138.67 sec; Iteration 4621 / 40000) loss: 1.797984
# (Time 138.91 sec; Iteration 4631 / 40000) loss: 1.727550
# (Time 139.17 sec; Iteration 4641 / 40000) loss: 1.897866
# (Time 139.41 sec; Iteration 4651 / 40000) loss: 1.676247
# (Time 139.65 sec; Iteration 4661 / 40000) loss: 1.716812
# (Time 139.89 sec; Iteration 4671 / 40000) loss: 1.779623
# (Time 140.15 sec; Iteration 4681 / 40000) loss: 1.642041
# (Time 140.39 sec; Iteration 4691 / 40000) loss: 1.738328
# (Time 140.64 sec; Iteration 4701 / 40000) loss: 1.762628
# (Time 140.89 sec; Iteration 4711 / 40000) loss: 1.702706
# (Time 141.14 sec; Iteration 4721 / 40000) loss: 1.730532
# (Time 141.39 sec; Iteration 4731 / 40000) loss: 1.723843
# (Time 141.64 sec; Iteration 4741 / 40000) loss: 1.693319
# (Time 141.88 sec; Iteration 4751 / 40000) loss: 1.819787
# (Time 142.13 sec; Iteration 4761 / 40000) loss: 1.709675
# (Time 142.38 sec; Iteration 4771 / 40000) loss: 1.630515
# (Time 142.63 sec; Iteration 4781 / 40000) loss: 1.697828
# (Time 142.88 sec; Iteration 4791 / 40000) loss: 1.417742
# cpu
# (Epoch 12 / 100) train acc: 0.373000; val_acc: 0.377600
# (Time 143.73 sec; Iteration 4801 / 40000) loss: 1.772364
# (Time 143.97 sec; Iteration 4811 / 40000) loss: 1.552114
# (Time 144.22 sec; Iteration 4821 / 40000) loss: 1.802362
# (Time 144.48 sec; Iteration 4831 / 40000) loss: 1.684559
# (Time 144.73 sec; Iteration 4841 / 40000) loss: 1.706579
# (Time 144.96 sec; Iteration 4851 / 40000) loss: 1.840465
# (Time 145.21 sec; Iteration 4861 / 40000) loss: 1.586115
# (Time 145.46 sec; Iteration 4871 / 40000) loss: 1.767896
# (Time 145.71 sec; Iteration 4881 / 40000) loss: 1.669988
# (Time 145.95 sec; Iteration 4891 / 40000) loss: 1.650688
# (Time 146.19 sec; Iteration 4901 / 40000) loss: 1.752149
# (Time 146.45 sec; Iteration 4911 / 40000) loss: 1.728154
# (Time 146.69 sec; Iteration 4921 / 40000) loss: 1.772889
# (Time 146.93 sec; Iteration 4931 / 40000) loss: 1.725477
# (Time 147.18 sec; Iteration 4941 / 40000) loss: 1.740948
# (Time 147.43 sec; Iteration 4951 / 40000) loss: 1.545499
# (Time 147.67 sec; Iteration 4961 / 40000) loss: 1.654573
# (Time 147.91 sec; Iteration 4971 / 40000) loss: 1.647876
# (Time 148.18 sec; Iteration 4981 / 40000) loss: 1.666309
# (Time 148.52 sec; Iteration 4991 / 40000) loss: 1.713624
# (Time 148.87 sec; Iteration 5001 / 40000) loss: 1.644214
# (Time 149.21 sec; Iteration 5011 / 40000) loss: 1.854835
# (Time 149.55 sec; Iteration 5021 / 40000) loss: 1.778835
# (Time 149.90 sec; Iteration 5031 / 40000) loss: 1.585871
# (Time 150.24 sec; Iteration 5041 / 40000) loss: 1.638979
# (Time 150.59 sec; Iteration 5051 / 40000) loss: 1.802308
# (Time 150.93 sec; Iteration 5061 / 40000) loss: 1.745556
# (Time 151.27 sec; Iteration 5071 / 40000) loss: 1.637376
# (Time 151.61 sec; Iteration 5081 / 40000) loss: 1.587875
# (Time 151.97 sec; Iteration 5091 / 40000) loss: 1.790871
# (Time 152.31 sec; Iteration 5101 / 40000) loss: 1.643154
# (Time 152.59 sec; Iteration 5111 / 40000) loss: 1.838065
# (Time 152.85 sec; Iteration 5121 / 40000) loss: 1.826533
# (Time 153.09 sec; Iteration 5131 / 40000) loss: 1.771126
# (Time 153.34 sec; Iteration 5141 / 40000) loss: 1.678903
# (Time 153.58 sec; Iteration 5151 / 40000) loss: 1.610361
# (Time 153.84 sec; Iteration 5161 / 40000) loss: 1.573455
# (Time 154.08 sec; Iteration 5171 / 40000) loss: 1.692755
# (Time 154.32 sec; Iteration 5181 / 40000) loss: 1.606145
# (Time 154.57 sec; Iteration 5191 / 40000) loss: 1.505742
# cpu
# (Epoch 13 / 100) train acc: 0.407000; val_acc: 0.383600
# (Time 155.38 sec; Iteration 5201 / 40000) loss: 1.538667
# (Time 155.61 sec; Iteration 5211 / 40000) loss: 1.575333
# (Time 155.88 sec; Iteration 5221 / 40000) loss: 1.598940
# (Time 156.12 sec; Iteration 5231 / 40000) loss: 1.696246
# (Time 156.36 sec; Iteration 5241 / 40000) loss: 1.747636
# (Time 156.60 sec; Iteration 5251 / 40000) loss: 1.550013
# (Time 156.85 sec; Iteration 5261 / 40000) loss: 1.540285
# (Time 157.08 sec; Iteration 5271 / 40000) loss: 1.788244
# (Time 157.32 sec; Iteration 5281 / 40000) loss: 1.701390
# (Time 157.56 sec; Iteration 5291 / 40000) loss: 1.639341
# (Time 157.81 sec; Iteration 5301 / 40000) loss: 1.810060
# (Time 158.05 sec; Iteration 5311 / 40000) loss: 1.734219
# (Time 158.30 sec; Iteration 5321 / 40000) loss: 1.666302
# (Time 158.54 sec; Iteration 5331 / 40000) loss: 1.709491
# (Time 158.79 sec; Iteration 5341 / 40000) loss: 1.575498
# (Time 159.04 sec; Iteration 5351 / 40000) loss: 1.719093
# (Time 159.28 sec; Iteration 5361 / 40000) loss: 1.571456
# (Time 159.52 sec; Iteration 5371 / 40000) loss: 1.636667
# (Time 159.76 sec; Iteration 5381 / 40000) loss: 1.692598
# (Time 160.01 sec; Iteration 5391 / 40000) loss: 1.611750
# (Time 160.25 sec; Iteration 5401 / 40000) loss: 1.673380
# (Time 160.50 sec; Iteration 5411 / 40000) loss: 1.701600
# (Time 160.74 sec; Iteration 5421 / 40000) loss: 1.859574
# (Time 160.95 sec; Iteration 5431 / 40000) loss: 1.647962
# (Time 161.16 sec; Iteration 5441 / 40000) loss: 1.670329
# (Time 161.36 sec; Iteration 5451 / 40000) loss: 1.606265
# (Time 161.56 sec; Iteration 5461 / 40000) loss: 1.565264
# (Time 161.79 sec; Iteration 5471 / 40000) loss: 1.689565
# (Time 162.05 sec; Iteration 5481 / 40000) loss: 1.540673
# (Time 162.29 sec; Iteration 5491 / 40000) loss: 1.748318
# (Time 162.55 sec; Iteration 5501 / 40000) loss: 1.677227
# (Time 162.89 sec; Iteration 5511 / 40000) loss: 1.471025
# (Time 163.25 sec; Iteration 5521 / 40000) loss: 1.732583
# (Time 163.58 sec; Iteration 5531 / 40000) loss: 1.694695
# (Time 163.91 sec; Iteration 5541 / 40000) loss: 1.706438
# (Time 164.27 sec; Iteration 5551 / 40000) loss: 1.608702
# (Time 164.60 sec; Iteration 5561 / 40000) loss: 1.607262
# (Time 164.93 sec; Iteration 5571 / 40000) loss: 1.709510
# (Time 165.28 sec; Iteration 5581 / 40000) loss: 1.735704
# (Time 165.63 sec; Iteration 5591 / 40000) loss: 1.763833
# cpu
# (Epoch 14 / 100) train acc: 0.402000; val_acc: 0.391300
# (Time 166.84 sec; Iteration 5601 / 40000) loss: 1.638915
# (Time 167.09 sec; Iteration 5611 / 40000) loss: 1.613328
# (Time 167.34 sec; Iteration 5621 / 40000) loss: 1.666237
# (Time 167.58 sec; Iteration 5631 / 40000) loss: 1.765057
# (Time 167.83 sec; Iteration 5641 / 40000) loss: 1.619232
# (Time 168.07 sec; Iteration 5651 / 40000) loss: 1.621440
# (Time 168.33 sec; Iteration 5661 / 40000) loss: 1.554486
# (Time 168.57 sec; Iteration 5671 / 40000) loss: 1.561337
# (Time 168.82 sec; Iteration 5681 / 40000) loss: 1.773499
# (Time 169.03 sec; Iteration 5691 / 40000) loss: 1.812966
# (Time 169.24 sec; Iteration 5701 / 40000) loss: 1.676091
# (Time 169.44 sec; Iteration 5711 / 40000) loss: 1.547977
# (Time 169.65 sec; Iteration 5721 / 40000) loss: 1.731226
# (Time 169.86 sec; Iteration 5731 / 40000) loss: 1.636710
# (Time 170.11 sec; Iteration 5741 / 40000) loss: 1.532069
# (Time 170.36 sec; Iteration 5751 / 40000) loss: 1.723124
# (Time 170.61 sec; Iteration 5761 / 40000) loss: 1.652240
# (Time 170.86 sec; Iteration 5771 / 40000) loss: 1.731218
# (Time 171.11 sec; Iteration 5781 / 40000) loss: 1.685300
# (Time 171.37 sec; Iteration 5791 / 40000) loss: 1.740489
# (Time 171.62 sec; Iteration 5801 / 40000) loss: 1.652357
# (Time 171.87 sec; Iteration 5811 / 40000) loss: 1.697964
# (Time 172.11 sec; Iteration 5821 / 40000) loss: 1.576531
# (Time 172.36 sec; Iteration 5831 / 40000) loss: 1.711208
# (Time 172.62 sec; Iteration 5841 / 40000) loss: 1.605706
# (Time 172.87 sec; Iteration 5851 / 40000) loss: 1.562508
# (Time 173.12 sec; Iteration 5861 / 40000) loss: 1.571757
# (Time 173.37 sec; Iteration 5871 / 40000) loss: 1.553519
# (Time 173.64 sec; Iteration 5881 / 40000) loss: 1.680242
# (Time 173.89 sec; Iteration 5891 / 40000) loss: 1.592012
# (Time 174.14 sec; Iteration 5901 / 40000) loss: 1.735388
# (Time 174.38 sec; Iteration 5911 / 40000) loss: 1.704591
# (Time 174.63 sec; Iteration 5921 / 40000) loss: 1.502077
# (Time 174.88 sec; Iteration 5931 / 40000) loss: 1.725132
# (Time 175.11 sec; Iteration 5941 / 40000) loss: 1.745864
# (Time 175.35 sec; Iteration 5951 / 40000) loss: 1.911720
# (Time 175.60 sec; Iteration 5961 / 40000) loss: 1.547214
# (Time 175.85 sec; Iteration 5971 / 40000) loss: 1.722062
# (Time 176.09 sec; Iteration 5981 / 40000) loss: 1.598316
# (Time 176.35 sec; Iteration 5991 / 40000) loss: 1.649020
# cpu
# (Epoch 15 / 100) train acc: 0.413000; val_acc: 0.400200
# (Time 177.36 sec; Iteration 6001 / 40000) loss: 1.616104
# (Time 177.71 sec; Iteration 6011 / 40000) loss: 1.649047
# (Time 178.05 sec; Iteration 6021 / 40000) loss: 1.723381
# (Time 178.38 sec; Iteration 6031 / 40000) loss: 1.645141
# (Time 178.73 sec; Iteration 6041 / 40000) loss: 1.710421
# (Time 179.07 sec; Iteration 6051 / 40000) loss: 1.734446
# (Time 179.41 sec; Iteration 6061 / 40000) loss: 1.519513
# (Time 179.77 sec; Iteration 6071 / 40000) loss: 1.722353
# (Time 180.11 sec; Iteration 6081 / 40000) loss: 1.726656
# (Time 180.45 sec; Iteration 6091 / 40000) loss: 1.526047
# (Time 180.79 sec; Iteration 6101 / 40000) loss: 1.710265
# (Time 181.13 sec; Iteration 6111 / 40000) loss: 1.782616
# (Time 181.39 sec; Iteration 6121 / 40000) loss: 1.682958
# (Time 181.64 sec; Iteration 6131 / 40000) loss: 1.572350
# (Time 181.90 sec; Iteration 6141 / 40000) loss: 1.594687
# (Time 182.15 sec; Iteration 6151 / 40000) loss: 1.665398
# (Time 182.39 sec; Iteration 6161 / 40000) loss: 1.595912
# (Time 182.65 sec; Iteration 6171 / 40000) loss: 1.634795
# (Time 182.90 sec; Iteration 6181 / 40000) loss: 1.714071
# (Time 183.15 sec; Iteration 6191 / 40000) loss: 1.787452
# (Time 183.40 sec; Iteration 6201 / 40000) loss: 1.742911
# (Time 183.65 sec; Iteration 6211 / 40000) loss: 1.728159
# (Time 183.90 sec; Iteration 6221 / 40000) loss: 1.756658
# (Time 184.16 sec; Iteration 6231 / 40000) loss: 1.901665
# (Time 184.41 sec; Iteration 6241 / 40000) loss: 1.569332
# (Time 184.67 sec; Iteration 6251 / 40000) loss: 1.495238
# (Time 184.93 sec; Iteration 6261 / 40000) loss: 1.616576
# (Time 185.18 sec; Iteration 6271 / 40000) loss: 1.415633
# (Time 185.43 sec; Iteration 6281 / 40000) loss: 1.600878
# (Time 185.68 sec; Iteration 6291 / 40000) loss: 1.866254
# (Time 185.93 sec; Iteration 6301 / 40000) loss: 1.639192
# (Time 186.19 sec; Iteration 6311 / 40000) loss: 1.693764
# (Time 186.45 sec; Iteration 6321 / 40000) loss: 1.626352
# (Time 186.69 sec; Iteration 6331 / 40000) loss: 1.604344
# (Time 186.94 sec; Iteration 6341 / 40000) loss: 1.763555
# (Time 187.20 sec; Iteration 6351 / 40000) loss: 1.774268
# (Time 187.44 sec; Iteration 6361 / 40000) loss: 1.587570
# (Time 187.69 sec; Iteration 6371 / 40000) loss: 1.602125
# (Time 187.93 sec; Iteration 6381 / 40000) loss: 1.734884
# (Time 188.19 sec; Iteration 6391 / 40000) loss: 1.593695
# cpu
# (Epoch 16 / 100) train acc: 0.427000; val_acc: 0.406200
# (Time 189.02 sec; Iteration 6401 / 40000) loss: 1.529065
# (Time 189.28 sec; Iteration 6411 / 40000) loss: 1.620643
# (Time 189.53 sec; Iteration 6421 / 40000) loss: 1.624912
# (Time 189.79 sec; Iteration 6431 / 40000) loss: 1.539810
# (Time 190.04 sec; Iteration 6441 / 40000) loss: 1.653231
# (Time 190.30 sec; Iteration 6451 / 40000) loss: 1.594338
# (Time 190.55 sec; Iteration 6461 / 40000) loss: 1.598664
# (Time 190.81 sec; Iteration 6471 / 40000) loss: 1.592425
# (Time 191.06 sec; Iteration 6481 / 40000) loss: 1.749996
# (Time 191.35 sec; Iteration 6491 / 40000) loss: 1.654741
# (Time 191.69 sec; Iteration 6501 / 40000) loss: 1.640112
# (Time 192.02 sec; Iteration 6511 / 40000) loss: 1.570266
# (Time 192.37 sec; Iteration 6521 / 40000) loss: 1.739202
# (Time 192.71 sec; Iteration 6531 / 40000) loss: 1.685220
# (Time 193.06 sec; Iteration 6541 / 40000) loss: 1.527823
# (Time 193.41 sec; Iteration 6551 / 40000) loss: 1.794976
# (Time 193.75 sec; Iteration 6561 / 40000) loss: 1.616492
# (Time 194.08 sec; Iteration 6571 / 40000) loss: 1.717109
# (Time 194.43 sec; Iteration 6581 / 40000) loss: 1.544827
# (Time 194.78 sec; Iteration 6591 / 40000) loss: 1.637589
# (Time 195.13 sec; Iteration 6601 / 40000) loss: 1.556833
# (Time 195.48 sec; Iteration 6611 / 40000) loss: 1.589683
# (Time 195.76 sec; Iteration 6621 / 40000) loss: 1.718313
# (Time 196.00 sec; Iteration 6631 / 40000) loss: 1.591236
# (Time 196.24 sec; Iteration 6641 / 40000) loss: 1.642325
# (Time 196.50 sec; Iteration 6651 / 40000) loss: 1.604045
# (Time 196.75 sec; Iteration 6661 / 40000) loss: 1.575192
# (Time 196.99 sec; Iteration 6671 / 40000) loss: 1.555094
# (Time 197.24 sec; Iteration 6681 / 40000) loss: 1.728479
# (Time 197.49 sec; Iteration 6691 / 40000) loss: 1.794291
# (Time 197.70 sec; Iteration 6701 / 40000) loss: 1.699038
# (Time 197.90 sec; Iteration 6711 / 40000) loss: 1.657862
# (Time 198.10 sec; Iteration 6721 / 40000) loss: 1.536241
# (Time 198.30 sec; Iteration 6731 / 40000) loss: 1.637880
# (Time 198.50 sec; Iteration 6741 / 40000) loss: 1.604907
# (Time 198.76 sec; Iteration 6751 / 40000) loss: 1.755268
# (Time 199.00 sec; Iteration 6761 / 40000) loss: 1.671363
# (Time 199.25 sec; Iteration 6771 / 40000) loss: 1.660777
# (Time 199.50 sec; Iteration 6781 / 40000) loss: 1.536190
# (Time 199.76 sec; Iteration 6791 / 40000) loss: 1.690694
# cpu
# (Epoch 17 / 100) train acc: 0.441000; val_acc: 0.414500
# (Time 200.60 sec; Iteration 6801 / 40000) loss: 1.553254
# (Time 200.86 sec; Iteration 6811 / 40000) loss: 1.564791
# (Time 201.12 sec; Iteration 6821 / 40000) loss: 1.640551
# (Time 201.37 sec; Iteration 6831 / 40000) loss: 1.752307
# (Time 201.62 sec; Iteration 6841 / 40000) loss: 1.650905
# (Time 201.88 sec; Iteration 6851 / 40000) loss: 1.571115
# (Time 202.13 sec; Iteration 6861 / 40000) loss: 1.677355
# (Time 202.37 sec; Iteration 6871 / 40000) loss: 1.605837
# (Time 202.63 sec; Iteration 6881 / 40000) loss: 1.611327
# (Time 202.90 sec; Iteration 6891 / 40000) loss: 1.643610
# (Time 203.15 sec; Iteration 6901 / 40000) loss: 1.530708
# (Time 203.41 sec; Iteration 6911 / 40000) loss: 1.457158
# (Time 203.66 sec; Iteration 6921 / 40000) loss: 1.658518
# (Time 203.88 sec; Iteration 6931 / 40000) loss: 1.736375
# (Time 204.08 sec; Iteration 6941 / 40000) loss: 1.690699
# (Time 204.29 sec; Iteration 6951 / 40000) loss: 1.635874
# (Time 204.50 sec; Iteration 6961 / 40000) loss: 1.637864
# (Time 204.71 sec; Iteration 6971 / 40000) loss: 1.693502
# (Time 204.98 sec; Iteration 6981 / 40000) loss: 1.551586
# (Time 205.23 sec; Iteration 6991 / 40000) loss: 1.685656
# (Time 205.47 sec; Iteration 7001 / 40000) loss: 1.501181
# (Time 205.77 sec; Iteration 7011 / 40000) loss: 1.514560
# (Time 206.12 sec; Iteration 7021 / 40000) loss: 1.487747
# (Time 206.49 sec; Iteration 7031 / 40000) loss: 1.493386
# (Time 207.40 sec; Iteration 7041 / 40000) loss: 1.443510
# (Time 207.75 sec; Iteration 7051 / 40000) loss: 1.705233
# (Time 208.11 sec; Iteration 7061 / 40000) loss: 1.516529
# (Time 208.45 sec; Iteration 7071 / 40000) loss: 1.682944
# (Time 208.78 sec; Iteration 7081 / 40000) loss: 1.626544
# (Time 209.13 sec; Iteration 7091 / 40000) loss: 1.720849
# (Time 209.47 sec; Iteration 7101 / 40000) loss: 1.483533
# (Time 209.83 sec; Iteration 7111 / 40000) loss: 1.507888
# (Time 210.18 sec; Iteration 7121 / 40000) loss: 1.566727
# (Time 210.42 sec; Iteration 7131 / 40000) loss: 1.514800
# (Time 210.68 sec; Iteration 7141 / 40000) loss: 1.619494
# (Time 210.92 sec; Iteration 7151 / 40000) loss: 1.687970
# (Time 211.18 sec; Iteration 7161 / 40000) loss: 1.689213
# (Time 211.44 sec; Iteration 7171 / 40000) loss: 1.542962
# (Time 211.70 sec; Iteration 7181 / 40000) loss: 1.661459
# (Time 211.94 sec; Iteration 7191 / 40000) loss: 1.950112
# cpu
# (Epoch 18 / 100) train acc: 0.437000; val_acc: 0.420400
# (Time 212.77 sec; Iteration 7201 / 40000) loss: 1.664930
# (Time 212.99 sec; Iteration 7211 / 40000) loss: 1.577771
# (Time 213.19 sec; Iteration 7221 / 40000) loss: 1.601490
# (Time 213.40 sec; Iteration 7231 / 40000) loss: 1.657883
# (Time 213.60 sec; Iteration 7241 / 40000) loss: 1.431841
# (Time 213.80 sec; Iteration 7251 / 40000) loss: 1.532155
# (Time 214.03 sec; Iteration 7261 / 40000) loss: 1.639835
# (Time 214.28 sec; Iteration 7271 / 40000) loss: 1.700401
# (Time 214.53 sec; Iteration 7281 / 40000) loss: 1.584252
# (Time 214.78 sec; Iteration 7291 / 40000) loss: 1.842525
# (Time 215.02 sec; Iteration 7301 / 40000) loss: 1.639895
# (Time 215.27 sec; Iteration 7311 / 40000) loss: 1.779012
# (Time 215.51 sec; Iteration 7321 / 40000) loss: 1.551515
# (Time 215.75 sec; Iteration 7331 / 40000) loss: 1.609451
# (Time 216.00 sec; Iteration 7341 / 40000) loss: 1.452483
# (Time 216.24 sec; Iteration 7351 / 40000) loss: 1.632822
# (Time 216.49 sec; Iteration 7361 / 40000) loss: 1.531322
# (Time 216.74 sec; Iteration 7371 / 40000) loss: 1.533436
# (Time 216.98 sec; Iteration 7381 / 40000) loss: 1.738173
# (Time 217.23 sec; Iteration 7391 / 40000) loss: 1.424246
# (Time 217.48 sec; Iteration 7401 / 40000) loss: 1.563526
# (Time 217.73 sec; Iteration 7411 / 40000) loss: 1.548944
# (Time 217.97 sec; Iteration 7421 / 40000) loss: 1.559551
# (Time 218.22 sec; Iteration 7431 / 40000) loss: 1.740306
# (Time 218.47 sec; Iteration 7441 / 40000) loss: 1.646132
# (Time 218.71 sec; Iteration 7451 / 40000) loss: 1.777381
# (Time 218.97 sec; Iteration 7461 / 40000) loss: 1.397111
# (Time 219.21 sec; Iteration 7471 / 40000) loss: 1.738294
# (Time 219.46 sec; Iteration 7481 / 40000) loss: 1.666983
# (Time 219.71 sec; Iteration 7491 / 40000) loss: 1.641487
# (Time 219.96 sec; Iteration 7501 / 40000) loss: 1.726157
# (Time 220.23 sec; Iteration 7511 / 40000) loss: 1.752323
# (Time 220.58 sec; Iteration 7521 / 40000) loss: 1.645267
# (Time 220.92 sec; Iteration 7531 / 40000) loss: 1.431146
# (Time 221.26 sec; Iteration 7541 / 40000) loss: 1.692453
# (Time 221.62 sec; Iteration 7551 / 40000) loss: 1.636516
# (Time 221.97 sec; Iteration 7561 / 40000) loss: 1.516483
# (Time 222.32 sec; Iteration 7571 / 40000) loss: 1.521706
# (Time 222.67 sec; Iteration 7581 / 40000) loss: 1.818020
# (Time 223.01 sec; Iteration 7591 / 40000) loss: 1.485826
# cpu
# (Epoch 19 / 100) train acc: 0.416000; val_acc: 0.428800
# (Time 224.25 sec; Iteration 7601 / 40000) loss: 1.527177
# (Time 224.55 sec; Iteration 7611 / 40000) loss: 1.439556
# (Time 224.81 sec; Iteration 7621 / 40000) loss: 1.621358
# (Time 225.05 sec; Iteration 7631 / 40000) loss: 1.612120
# (Time 225.30 sec; Iteration 7641 / 40000) loss: 1.570192
# (Time 225.54 sec; Iteration 7651 / 40000) loss: 1.557483
# (Time 225.81 sec; Iteration 7661 / 40000) loss: 1.564662
# (Time 226.05 sec; Iteration 7671 / 40000) loss: 1.641114
# (Time 226.31 sec; Iteration 7681 / 40000) loss: 1.571954
# (Time 226.55 sec; Iteration 7691 / 40000) loss: 1.601226
# (Time 226.82 sec; Iteration 7701 / 40000) loss: 1.530779
# (Time 227.07 sec; Iteration 7711 / 40000) loss: 1.697114
# (Time 227.33 sec; Iteration 7721 / 40000) loss: 1.650802
# (Time 227.57 sec; Iteration 7731 / 40000) loss: 1.568738
# (Time 227.82 sec; Iteration 7741 / 40000) loss: 1.476120
# (Time 228.07 sec; Iteration 7751 / 40000) loss: 1.545853
# (Time 228.32 sec; Iteration 7761 / 40000) loss: 1.553334
# (Time 228.56 sec; Iteration 7771 / 40000) loss: 1.672777
# (Time 228.81 sec; Iteration 7781 / 40000) loss: 1.461427
# (Time 229.07 sec; Iteration 7791 / 40000) loss: 1.523387
# (Time 229.32 sec; Iteration 7801 / 40000) loss: 1.619291
# (Time 229.56 sec; Iteration 7811 / 40000) loss: 1.755392
# (Time 229.81 sec; Iteration 7821 / 40000) loss: 1.748265
# (Time 230.07 sec; Iteration 7831 / 40000) loss: 1.626046
# (Time 230.31 sec; Iteration 7841 / 40000) loss: 1.637910
# (Time 230.55 sec; Iteration 7851 / 40000) loss: 1.589306
# (Time 230.80 sec; Iteration 7861 / 40000) loss: 1.519047
# (Time 231.06 sec; Iteration 7871 / 40000) loss: 1.624921
# (Time 231.31 sec; Iteration 7881 / 40000) loss: 1.660685
# (Time 231.57 sec; Iteration 7891 / 40000) loss: 1.625331
# (Time 231.82 sec; Iteration 7901 / 40000) loss: 1.394194
# (Time 232.08 sec; Iteration 7911 / 40000) loss: 1.654011
# (Time 232.32 sec; Iteration 7921 / 40000) loss: 1.689783
# (Time 232.58 sec; Iteration 7931 / 40000) loss: 1.670724
# (Time 232.83 sec; Iteration 7941 / 40000) loss: 1.641346
# (Time 233.09 sec; Iteration 7951 / 40000) loss: 1.494141
# (Time 233.34 sec; Iteration 7961 / 40000) loss: 1.549415
# (Time 233.60 sec; Iteration 7971 / 40000) loss: 1.619811
# (Time 233.84 sec; Iteration 7981 / 40000) loss: 1.533274
# (Time 234.10 sec; Iteration 7991 / 40000) loss: 1.432412
# cpu
# (Epoch 20 / 100) train acc: 0.430000; val_acc: 0.428700
# (Time 235.18 sec; Iteration 8001 / 40000) loss: 1.566670
# (Time 235.53 sec; Iteration 8011 / 40000) loss: 1.515888
# (Time 235.87 sec; Iteration 8021 / 40000) loss: 1.608058
# (Time 236.21 sec; Iteration 8031 / 40000) loss: 1.523132
# (Time 236.55 sec; Iteration 8041 / 40000) loss: 1.633316
# (Time 236.90 sec; Iteration 8051 / 40000) loss: 1.661189
# (Time 237.23 sec; Iteration 8061 / 40000) loss: 1.681235
# (Time 237.58 sec; Iteration 8071 / 40000) loss: 1.712440
# (Time 237.92 sec; Iteration 8081 / 40000) loss: 1.702557
# (Time 238.26 sec; Iteration 8091 / 40000) loss: 1.640118
# (Time 238.61 sec; Iteration 8101 / 40000) loss: 1.489046
# (Time 238.92 sec; Iteration 8111 / 40000) loss: 1.518374
# (Time 239.16 sec; Iteration 8121 / 40000) loss: 1.676099
# (Time 239.41 sec; Iteration 8131 / 40000) loss: 1.660220
# (Time 239.67 sec; Iteration 8141 / 40000) loss: 1.611819
# (Time 239.92 sec; Iteration 8151 / 40000) loss: 1.602284
# (Time 240.17 sec; Iteration 8161 / 40000) loss: 1.550955
# (Time 240.42 sec; Iteration 8171 / 40000) loss: 1.618891
# (Time 240.67 sec; Iteration 8181 / 40000) loss: 1.462846
# (Time 240.92 sec; Iteration 8191 / 40000) loss: 1.547141
# (Time 241.16 sec; Iteration 8201 / 40000) loss: 1.570073
# (Time 241.42 sec; Iteration 8211 / 40000) loss: 1.453847
# (Time 241.69 sec; Iteration 8221 / 40000) loss: 1.615004
# (Time 241.94 sec; Iteration 8231 / 40000) loss: 1.613903
# (Time 242.19 sec; Iteration 8241 / 40000) loss: 1.726563
# (Time 242.45 sec; Iteration 8251 / 40000) loss: 1.444782
# (Time 242.70 sec; Iteration 8261 / 40000) loss: 1.585405
# (Time 242.95 sec; Iteration 8271 / 40000) loss: 1.582356
# ...
# (Time 1077.70 sec; Iteration 37361 / 40000) loss: 1.150578
# (Time 1077.94 sec; Iteration 37371 / 40000) loss: 1.313669
# (Time 1078.19 sec; Iteration 37381 / 40000) loss: 0.998938
# (Time 1078.45 sec; Iteration 37391 / 40000) loss: 0.994247
# (Time 1078.69 sec; Iteration 37401 / 40000) loss: 0.961107
# (Time 1078.93 sec; Iteration 37411 / 40000) loss: 1.089859
# (Time 1079.18 sec; Iteration 37421 / 40000) loss: 1.206960
# (Time 1079.43 sec; Iteration 37431 / 40000) loss: 1.150329
# (Time 1079.68 sec; Iteration 37441 / 40000) loss: 0.973179
# (Time 1079.91 sec; Iteration 37451 / 40000) loss: 0.947541
# (Time 1080.18 sec; Iteration 37461 / 40000) loss: 1.082178
# (Time 1080.42 sec; Iteration 37471 / 40000) loss: 1.088014
# (Time 1080.67 sec; Iteration 37481 / 40000) loss: 0.952352
# (Time 1080.92 sec; Iteration 37491 / 40000) loss: 1.002476
# (Time 1081.17 sec; Iteration 37501 / 40000) loss: 0.977606
# (Time 1081.43 sec; Iteration 37511 / 40000) loss: 1.039679
# (Time 1081.68 sec; Iteration 37521 / 40000) loss: 1.126017
# (Time 1081.94 sec; Iteration 37531 / 40000) loss: 0.995603
# (Time 1082.19 sec; Iteration 37541 / 40000) loss: 0.960426
# (Time 1082.44 sec; Iteration 37551 / 40000) loss: 1.146688
# (Time 1082.70 sec; Iteration 37561 / 40000) loss: 1.100578
# (Time 1082.96 sec; Iteration 37571 / 40000) loss: 1.128598
# (Time 1083.22 sec; Iteration 37581 / 40000) loss: 0.938278
# (Time 1083.47 sec; Iteration 37591 / 40000) loss: 0.800482
# cpu
# (Epoch 94 / 100) train acc: 0.657000; val_acc: 0.529700
# (Time 1084.32 sec; Iteration 37601 / 40000) loss: 0.915266
# (Time 1084.56 sec; Iteration 37611 / 40000) loss: 1.084954
# (Time 1084.81 sec; Iteration 37621 / 40000) loss: 1.322899
# (Time 1085.07 sec; Iteration 37631 / 40000) loss: 1.058268
# (Time 1085.38 sec; Iteration 37641 / 40000) loss: 0.928824
# (Time 1085.73 sec; Iteration 37651 / 40000) loss: 1.152008
# (Time 1086.07 sec; Iteration 37661 / 40000) loss: 0.951479
# (Time 1086.42 sec; Iteration 37671 / 40000) loss: 1.051656
# (Time 1086.77 sec; Iteration 37681 / 40000) loss: 0.989056
# (Time 1087.11 sec; Iteration 37691 / 40000) loss: 1.174863
# (Time 1087.46 sec; Iteration 37701 / 40000) loss: 1.077207
# (Time 1087.81 sec; Iteration 37711 / 40000) loss: 1.094168
# (Time 1088.16 sec; Iteration 37721 / 40000) loss: 1.096042
# (Time 1088.50 sec; Iteration 37731 / 40000) loss: 1.053423
# (Time 1088.78 sec; Iteration 37741 / 40000) loss: 1.105655
# (Time 1089.04 sec; Iteration 37751 / 40000) loss: 0.899194
# (Time 1089.30 sec; Iteration 37761 / 40000) loss: 1.132505
# (Time 1089.54 sec; Iteration 37771 / 40000) loss: 0.973501
# (Time 1089.80 sec; Iteration 37781 / 40000) loss: 0.880962
# (Time 1090.06 sec; Iteration 37791 / 40000) loss: 1.076561
# (Time 1090.32 sec; Iteration 37801 / 40000) loss: 1.113021
# (Time 1090.57 sec; Iteration 37811 / 40000) loss: 1.006316
# (Time 1090.82 sec; Iteration 37821 / 40000) loss: 1.062621
# (Time 1091.09 sec; Iteration 37831 / 40000) loss: 0.907768
# (Time 1091.33 sec; Iteration 37841 / 40000) loss: 1.032608
# (Time 1091.57 sec; Iteration 37851 / 40000) loss: 1.126696
# (Time 1091.81 sec; Iteration 37861 / 40000) loss: 1.022080
# (Time 1092.07 sec; Iteration 37871 / 40000) loss: 0.980016
# (Time 1092.31 sec; Iteration 37881 / 40000) loss: 0.976578
# (Time 1092.54 sec; Iteration 37891 / 40000) loss: 1.057843
# (Time 1092.78 sec; Iteration 37901 / 40000) loss: 1.156596
# (Time 1093.02 sec; Iteration 37911 / 40000) loss: 1.076314
# (Time 1093.28 sec; Iteration 37921 / 40000) loss: 0.963406
# (Time 1093.53 sec; Iteration 37931 / 40000) loss: 1.168208
# (Time 1093.78 sec; Iteration 37941 / 40000) loss: 0.953385
# (Time 1094.03 sec; Iteration 37951 / 40000) loss: 0.899834
# (Time 1094.29 sec; Iteration 37961 / 40000) loss: 1.219293
# (Time 1094.53 sec; Iteration 37971 / 40000) loss: 1.045714
# (Time 1094.78 sec; Iteration 37981 / 40000) loss: 0.976498
# (Time 1095.05 sec; Iteration 37991 / 40000) loss: 1.033925
# cpu
# (Epoch 95 / 100) train acc: 0.641000; val_acc: 0.526100
# (Time 1095.89 sec; Iteration 38001 / 40000) loss: 1.006238
# (Time 1096.14 sec; Iteration 38011 / 40000) loss: 1.038306
# (Time 1096.39 sec; Iteration 38021 / 40000) loss: 1.024654
# (Time 1096.64 sec; Iteration 38031 / 40000) loss: 1.044386
# (Time 1096.89 sec; Iteration 38041 / 40000) loss: 1.153544
# (Time 1097.15 sec; Iteration 38051 / 40000) loss: 0.992264
# (Time 1097.39 sec; Iteration 38061 / 40000) loss: 0.898030
# (Time 1097.65 sec; Iteration 38071 / 40000) loss: 1.046029
# (Time 1097.90 sec; Iteration 38081 / 40000) loss: 1.046555
# (Time 1098.17 sec; Iteration 38091 / 40000) loss: 1.099935
# (Time 1098.41 sec; Iteration 38101 / 40000) loss: 1.177650
# (Time 1098.69 sec; Iteration 38111 / 40000) loss: 1.129532
# (Time 1099.03 sec; Iteration 38121 / 40000) loss: 1.018795
# (Time 1099.37 sec; Iteration 38131 / 40000) loss: 0.933909
# (Time 1099.70 sec; Iteration 38141 / 40000) loss: 0.898008
# (Time 1100.03 sec; Iteration 38151 / 40000) loss: 1.069283
# (Time 1100.38 sec; Iteration 38161 / 40000) loss: 1.069143
# (Time 1100.72 sec; Iteration 38171 / 40000) loss: 1.079312
# (Time 1101.05 sec; Iteration 38181 / 40000) loss: 0.891326
# (Time 1101.42 sec; Iteration 38191 / 40000) loss: 1.067224
# (Time 1101.76 sec; Iteration 38201 / 40000) loss: 1.044693
# (Time 1102.10 sec; Iteration 38211 / 40000) loss: 1.051623
# (Time 1102.39 sec; Iteration 38221 / 40000) loss: 1.153783
# (Time 1102.65 sec; Iteration 38231 / 40000) loss: 1.037252
# (Time 1102.89 sec; Iteration 38241 / 40000) loss: 1.023293
# (Time 1103.15 sec; Iteration 38251 / 40000) loss: 0.901325
# (Time 1103.40 sec; Iteration 38261 / 40000) loss: 0.899447
# (Time 1103.65 sec; Iteration 38271 / 40000) loss: 1.169057
# (Time 1103.89 sec; Iteration 38281 / 40000) loss: 0.998774
# (Time 1104.13 sec; Iteration 38291 / 40000) loss: 0.944833
# (Time 1104.36 sec; Iteration 38301 / 40000) loss: 1.018665
# (Time 1104.63 sec; Iteration 38311 / 40000) loss: 1.140437
# (Time 1104.86 sec; Iteration 38321 / 40000) loss: 0.984318
# (Time 1105.10 sec; Iteration 38331 / 40000) loss: 1.050178
# (Time 1105.35 sec; Iteration 38341 / 40000) loss: 1.220784
# (Time 1105.61 sec; Iteration 38351 / 40000) loss: 0.867541
# (Time 1105.86 sec; Iteration 38361 / 40000) loss: 1.064235
# (Time 1106.11 sec; Iteration 38371 / 40000) loss: 1.080148
# (Time 1106.36 sec; Iteration 38381 / 40000) loss: 0.965666
# (Time 1106.61 sec; Iteration 38391 / 40000) loss: 1.009413
# cpu
# (Epoch 96 / 100) train acc: 0.643000; val_acc: 0.530500
# (Time 1107.44 sec; Iteration 38401 / 40000) loss: 0.966367
# (Time 1107.69 sec; Iteration 38411 / 40000) loss: 1.008164
# (Time 1107.93 sec; Iteration 38421 / 40000) loss: 0.939517
# (Time 1108.18 sec; Iteration 38431 / 40000) loss: 1.018176
# (Time 1108.42 sec; Iteration 38441 / 40000) loss: 1.029068
# (Time 1108.68 sec; Iteration 38451 / 40000) loss: 1.057984
# (Time 1108.93 sec; Iteration 38461 / 40000) loss: 0.984681
# (Time 1109.18 sec; Iteration 38471 / 40000) loss: 1.004032
# (Time 1109.43 sec; Iteration 38481 / 40000) loss: 1.058114
# (Time 1109.69 sec; Iteration 38491 / 40000) loss: 0.819928
# (Time 1109.94 sec; Iteration 38501 / 40000) loss: 1.064304
# (Time 1110.21 sec; Iteration 38511 / 40000) loss: 1.033446
# (Time 1110.46 sec; Iteration 38521 / 40000) loss: 1.200136
# (Time 1110.72 sec; Iteration 38531 / 40000) loss: 1.056090
# (Time 1110.97 sec; Iteration 38541 / 40000) loss: 1.059819
# (Time 1111.23 sec; Iteration 38551 / 40000) loss: 0.998509
# (Time 1111.47 sec; Iteration 38561 / 40000) loss: 1.147964
# (Time 1111.74 sec; Iteration 38571 / 40000) loss: 1.111126
# (Time 1111.98 sec; Iteration 38581 / 40000) loss: 0.939648
# (Time 1112.24 sec; Iteration 38591 / 40000) loss: 1.006789
# (Time 1112.58 sec; Iteration 38601 / 40000) loss: 0.946624
# (Time 1112.93 sec; Iteration 38611 / 40000) loss: 0.893911
# (Time 1113.29 sec; Iteration 38621 / 40000) loss: 1.162644
# (Time 1113.63 sec; Iteration 38631 / 40000) loss: 1.273375
# (Time 1113.98 sec; Iteration 38641 / 40000) loss: 0.989223
# (Time 1114.33 sec; Iteration 38651 / 40000) loss: 1.136324
# (Time 1114.67 sec; Iteration 38661 / 40000) loss: 1.126182
# (Time 1115.01 sec; Iteration 38671 / 40000) loss: 1.090091
# (Time 1115.34 sec; Iteration 38681 / 40000) loss: 1.002511
# (Time 1115.68 sec; Iteration 38691 / 40000) loss: 1.050516
# (Time 1115.94 sec; Iteration 38701 / 40000) loss: 1.261383
# (Time 1116.19 sec; Iteration 38711 / 40000) loss: 1.120973
# (Time 1116.43 sec; Iteration 38721 / 40000) loss: 1.103616
# (Time 1116.68 sec; Iteration 38731 / 40000) loss: 1.036366
# (Time 1116.93 sec; Iteration 38741 / 40000) loss: 0.948189
# (Time 1117.18 sec; Iteration 38751 / 40000) loss: 1.031371
# (Time 1117.43 sec; Iteration 38761 / 40000) loss: 0.950937
# (Time 1117.69 sec; Iteration 38771 / 40000) loss: 0.973897
# (Time 1117.94 sec; Iteration 38781 / 40000) loss: 1.040912
# (Time 1118.20 sec; Iteration 38791 / 40000) loss: 0.978061
# cpu
# (Epoch 97 / 100) train acc: 0.636000; val_acc: 0.526000
# (Time 1119.04 sec; Iteration 38801 / 40000) loss: 1.052006
# (Time 1119.30 sec; Iteration 38811 / 40000) loss: 0.994702
# (Time 1119.55 sec; Iteration 38821 / 40000) loss: 1.140319
# (Time 1119.80 sec; Iteration 38831 / 40000) loss: 0.879114
# (Time 1120.05 sec; Iteration 38841 / 40000) loss: 1.070984
# (Time 1120.30 sec; Iteration 38851 / 40000) loss: 1.165451
# (Time 1120.55 sec; Iteration 38861 / 40000) loss: 0.973870
# (Time 1120.80 sec; Iteration 38871 / 40000) loss: 1.081103
# (Time 1121.05 sec; Iteration 38881 / 40000) loss: 1.006014
# (Time 1121.31 sec; Iteration 38891 / 40000) loss: 0.925263
# (Time 1121.56 sec; Iteration 38901 / 40000) loss: 0.903326
# (Time 1121.81 sec; Iteration 38911 / 40000) loss: 1.066752
# (Time 1122.05 sec; Iteration 38921 / 40000) loss: 0.975437
# (Time 1122.32 sec; Iteration 38931 / 40000) loss: 1.080487
# (Time 1122.58 sec; Iteration 38941 / 40000) loss: 1.085118
# (Time 1122.83 sec; Iteration 38951 / 40000) loss: 1.011719
# (Time 1123.09 sec; Iteration 38961 / 40000) loss: 0.975464
# (Time 1123.35 sec; Iteration 38971 / 40000) loss: 1.068459
# (Time 1123.60 sec; Iteration 38981 / 40000) loss: 1.195491
# (Time 1123.87 sec; Iteration 38991 / 40000) loss: 1.044249
# (Time 1124.12 sec; Iteration 39001 / 40000) loss: 1.128761
# (Time 1124.39 sec; Iteration 39011 / 40000) loss: 0.920384
# (Time 1124.64 sec; Iteration 39021 / 40000) loss: 0.925920
# (Time 1124.90 sec; Iteration 39031 / 40000) loss: 0.990186
# (Time 1125.15 sec; Iteration 39041 / 40000) loss: 1.097215
# (Time 1125.42 sec; Iteration 39051 / 40000) loss: 1.174509
# (Time 1125.67 sec; Iteration 39061 / 40000) loss: 1.089795
# (Time 1126.01 sec; Iteration 39071 / 40000) loss: 0.882916
# (Time 1126.36 sec; Iteration 39081 / 40000) loss: 1.076153
# (Time 1126.70 sec; Iteration 39091 / 40000) loss: 1.233430
# (Time 1127.05 sec; Iteration 39101 / 40000) loss: 1.110216
# (Time 1127.40 sec; Iteration 39111 / 40000) loss: 1.062903
# (Time 1127.76 sec; Iteration 39121 / 40000) loss: 1.114377
# (Time 1128.10 sec; Iteration 39131 / 40000) loss: 1.053271
# (Time 1128.44 sec; Iteration 39141 / 40000) loss: 1.009367
# (Time 1128.82 sec; Iteration 39151 / 40000) loss: 1.043763
# (Time 1129.17 sec; Iteration 39161 / 40000) loss: 1.088857
# (Time 1129.42 sec; Iteration 39171 / 40000) loss: 0.939720
# (Time 1129.68 sec; Iteration 39181 / 40000) loss: 0.966206
# (Time 1129.93 sec; Iteration 39191 / 40000) loss: 0.970062
# cpu
# (Epoch 98 / 100) train acc: 0.661000; val_acc: 0.528200
# (Time 1130.80 sec; Iteration 39201 / 40000) loss: 1.029801
# (Time 1131.03 sec; Iteration 39211 / 40000) loss: 1.121109
# (Time 1131.29 sec; Iteration 39221 / 40000) loss: 0.978485
# (Time 1131.56 sec; Iteration 39231 / 40000) loss: 1.244503
# (Time 1131.82 sec; Iteration 39241 / 40000) loss: 1.079207
# (Time 1132.07 sec; Iteration 39251 / 40000) loss: 1.089968
# (Time 1132.33 sec; Iteration 39261 / 40000) loss: 1.036031
# (Time 1132.59 sec; Iteration 39271 / 40000) loss: 1.023675
# (Time 1132.84 sec; Iteration 39281 / 40000) loss: 0.986760
# (Time 1133.10 sec; Iteration 39291 / 40000) loss: 1.061933
# (Time 1133.36 sec; Iteration 39301 / 40000) loss: 0.964308
# (Time 1133.63 sec; Iteration 39311 / 40000) loss: 1.008242
# (Time 1133.89 sec; Iteration 39321 / 40000) loss: 1.025594
# (Time 1134.16 sec; Iteration 39331 / 40000) loss: 1.042083
# (Time 1134.41 sec; Iteration 39341 / 40000) loss: 0.903824
# (Time 1134.68 sec; Iteration 39351 / 40000) loss: 0.888468
# (Time 1134.93 sec; Iteration 39361 / 40000) loss: 0.880245
# (Time 1135.18 sec; Iteration 39371 / 40000) loss: 1.000045
# (Time 1135.42 sec; Iteration 39381 / 40000) loss: 0.908972
# (Time 1135.68 sec; Iteration 39391 / 40000) loss: 0.889315
# (Time 1135.94 sec; Iteration 39401 / 40000) loss: 1.075214
# (Time 1136.20 sec; Iteration 39411 / 40000) loss: 0.977260
# (Time 1136.46 sec; Iteration 39421 / 40000) loss: 1.063806
# (Time 1136.70 sec; Iteration 39431 / 40000) loss: 0.961884
# (Time 1136.96 sec; Iteration 39441 / 40000) loss: 0.889183
# (Time 1137.21 sec; Iteration 39451 / 40000) loss: 1.088506
# (Time 1137.45 sec; Iteration 39461 / 40000) loss: 1.016479
# (Time 1137.70 sec; Iteration 39471 / 40000) loss: 0.873120
# (Time 1137.95 sec; Iteration 39481 / 40000) loss: 1.102034
# (Time 1138.19 sec; Iteration 39491 / 40000) loss: 0.952011
# (Time 1138.42 sec; Iteration 39501 / 40000) loss: 1.057237
# (Time 1138.67 sec; Iteration 39511 / 40000) loss: 0.996975
# (Time 1138.93 sec; Iteration 39521 / 40000) loss: 0.999802
# (Time 1139.20 sec; Iteration 39531 / 40000) loss: 1.234308
# (Time 1139.55 sec; Iteration 39541 / 40000) loss: 1.027675
# (Time 1139.90 sec; Iteration 39551 / 40000) loss: 0.948353
# (Time 1140.25 sec; Iteration 39561 / 40000) loss: 1.213462
# (Time 1140.58 sec; Iteration 39571 / 40000) loss: 0.916663
# (Time 1140.93 sec; Iteration 39581 / 40000) loss: 0.963003
# (Time 1141.28 sec; Iteration 39591 / 40000) loss: 1.058515
# cpu
# (Epoch 99 / 100) train acc: 0.658000; val_acc: 0.530400
# (Time 1142.56 sec; Iteration 39601 / 40000) loss: 1.089467
# (Time 1142.84 sec; Iteration 39611 / 40000) loss: 0.896815
# (Time 1143.10 sec; Iteration 39621 / 40000) loss: 1.001774
# (Time 1143.35 sec; Iteration 39631 / 40000) loss: 1.096489
# (Time 1143.61 sec; Iteration 39641 / 40000) loss: 1.199671
# (Time 1143.87 sec; Iteration 39651 / 40000) loss: 0.990670
# (Time 1144.13 sec; Iteration 39661 / 40000) loss: 0.979872
# (Time 1144.38 sec; Iteration 39671 / 40000) loss: 1.013990
# (Time 1144.64 sec; Iteration 39681 / 40000) loss: 0.964365
# (Time 1144.89 sec; Iteration 39691 / 40000) loss: 1.081913
# (Time 1145.16 sec; Iteration 39701 / 40000) loss: 1.200337
# (Time 1145.41 sec; Iteration 39711 / 40000) loss: 0.850026
# (Time 1145.67 sec; Iteration 39721 / 40000) loss: 1.162537
# (Time 1145.92 sec; Iteration 39731 / 40000) loss: 0.927431
# (Time 1146.19 sec; Iteration 39741 / 40000) loss: 0.957755
# (Time 1146.44 sec; Iteration 39751 / 40000) loss: 1.040164
# (Time 1146.68 sec; Iteration 39761 / 40000) loss: 0.970740
# (Time 1146.93 sec; Iteration 39771 / 40000) loss: 0.913324
# (Time 1147.20 sec; Iteration 39781 / 40000) loss: 1.031010
# (Time 1147.45 sec; Iteration 39791 / 40000) loss: 0.975484
# (Time 1147.69 sec; Iteration 39801 / 40000) loss: 0.951204
# (Time 1147.93 sec; Iteration 39811 / 40000) loss: 0.899104
# (Time 1148.18 sec; Iteration 39821 / 40000) loss: 0.988440
# (Time 1148.43 sec; Iteration 39831 / 40000) loss: 0.992427
# (Time 1148.67 sec; Iteration 39841 / 40000) loss: 1.099052
# (Time 1148.91 sec; Iteration 39851 / 40000) loss: 0.953736
# (Time 1149.15 sec; Iteration 39861 / 40000) loss: 1.025727
# (Time 1149.40 sec; Iteration 39871 / 40000) loss: 0.983326
# (Time 1149.65 sec; Iteration 39881 / 40000) loss: 0.907855
# (Time 1149.91 sec; Iteration 39891 / 40000) loss: 1.015494
# (Time 1150.16 sec; Iteration 39901 / 40000) loss: 0.954968
# (Time 1150.42 sec; Iteration 39911 / 40000) loss: 0.886894
# (Time 1150.68 sec; Iteration 39921 / 40000) loss: 1.107836
# (Time 1150.94 sec; Iteration 39931 / 40000) loss: 1.057181
# (Time 1151.19 sec; Iteration 39941 / 40000) loss: 1.027168
# (Time 1151.45 sec; Iteration 39951 / 40000) loss: 1.025570
# (Time 1151.70 sec; Iteration 39961 / 40000) loss: 0.973273
# (Time 1151.95 sec; Iteration 39971 / 40000) loss: 1.074802
# (Time 1152.21 sec; Iteration 39981 / 40000) loss: 1.158707
# (Time 1152.47 sec; Iteration 39991 / 40000) loss: 1.282817
# cpu
# (Epoch 100 / 100) train acc: 0.640000; val_acc: 0.529600

# %%
# Run this cell to visualize training loss and train / val accuracy
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# # Multilayer network
# On the lines of Two-layer Fully-Connected NN, you have to now implement a Fully-Connected NN which can create model architecture of arbitrary depth. You can ignore incorporating drop out into the code for now.
#
# Read through the `FullyConnectedNet` class in `fully_connected_networks.py`.
#
# Note: Backpropogation/Backward pass has already been implemented for your convinience.

# %% [markdown]
# ## Initial loss and gradient check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. Do the initial losses seem reasonable?
#
# For gradient checking, you should expect to see errors less than `1e-6`, except for the check on `W1` and `W2` with `reg=0` where your errors should be less than `1e-5`.

# %%
from fully_connected_networks import FullyConnectedNet

cs6476.utils.reset_seed(903322690)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device='cpu')
y = torch.randint(C, size=(N,), dtype=torch.int64, device='cpu')

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=torch.float64,
        device='cpu'
  )

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = cs6476.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, cs6476.grad.rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3007515088525388
# W1 relative error: 5.68e-08
# W2 relative error: 9.15e-08
# W3 relative error: 3.59e-08
# b1 relative error: 1.83e-07
# b2 relative error: 4.43e-08
# b3 relative error: 3.03e-09
# Running check with reg =  3.14
# Initial loss:  11.790525475042056
# W1 relative error: 8.72e-09
# W2 relative error: 6.98e-09
# W3 relative error: 8.81e-09
# b1 relative error: 3.31e-07
# b2 relative error: 7.43e-08
# b3 relative error: 1.27e-08

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement one of the most commonly used update rules and compare it to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# We provide the implementation of the SGD update rule for your reference in `fully_connected_networks.py`
#
# Now **implement** the SGD+Momentum update rule using the same interface. Run the following to check your implementation of SGD+Momentum. You should see errors less than `1e-7`.

# %%
from fully_connected_networks import sgd_momentum

cs6476.utils.reset_seed(903322690)

N, D = 4, 5
w = torch.linspace(-0.4, 0.6, steps=N*D, dtype=torch.float64, device='cpu').reshape(N, D)
dw = torch.linspace(-0.6, 0.4, steps=N*D, dtype=torch.float64, device='cpu').reshape(N, D)
v = torch.linspace(0.6, 0.9, steps=N*D, dtype=torch.float64, device='cpu').reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = torch.tensor([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]],
   dtype=torch.float64)#, device='cuda'
expected_velocity = torch.tensor([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]],
   dtype=torch.float64, device='cpu')

# Should see relative errors around e-8 or less
print('next_w error: ', cs6476.grad.rel_error(next_w, expected_next_w))
print('velocity error: ', cs6476.grad.rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  1.6802078709310813e-09
# velocity error:  2.9254212825785614e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
from fully_connected_networks import FullyConnectedNet, sgd, sgd_momentum,adam

# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.
cs6476.utils.reset_seed(903322690)

num_train = 4000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}

solvers = {}

for update_rule_name, update_rule_fn in [('sgd', sgd), ('sgd_momentum', sgd_momentum)]:
  print('running with ', update_rule_name)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2,
                            dtype=torch.float32)#, device='cuda'

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule_fn,
                  optim_config={
                    'learning_rate': 5e-2,
                  },
                  print_every=1000,
                  verbose=True, device='cpu')#
  solvers[update_rule_name] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')
for update_rule, solver in solvers.items():
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)


plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')
for update_rule, solver in solvers.items():
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
plt.legend(loc='lower center', ncol=4)

plt.gcf().set_size_inches(10, 20)
plt.show()
# Out:
# running with  sgd
# (Time 0.05 sec; Iteration 1 / 200) loss: 2.302542
# cpu
# (Epoch 0 / 5) train acc: 0.093000; val_acc: 0.096400
# cpu
# (Epoch 1 / 5) train acc: 0.133000; val_acc: 0.125700
# cpu
# (Epoch 2 / 5) train acc: 0.119000; val_acc: 0.117800
# cpu
# (Epoch 3 / 5) train acc: 0.137000; val_acc: 0.125900
# cpu
# (Epoch 4 / 5) train acc: 0.141000; val_acc: 0.141700
# cpu
# (Epoch 5 / 5) train acc: 0.107000; val_acc: 0.100300
#
# running with  sgd_momentum
# (Time 0.01 sec; Iteration 1 / 200) loss: 2.302072
# cpu
# (Epoch 0 / 5) train acc: 0.104000; val_acc: 0.098900
# cpu
# (Epoch 1 / 5) train acc: 0.104000; val_acc: 0.102200
# cpu
# (Epoch 2 / 5) train acc: 0.157000; val_acc: 0.152100
# cpu
# (Epoch 3 / 5) train acc: 0.243000; val_acc: 0.211700
# cpu
# (Epoch 4 / 5) train acc: 0.243000; val_acc: 0.241400
# cpu
# (Epoch 5 / 5) train acc: 0.269000; val_acc: 0.252000

# %% [markdown]
# # Dropout
# Dropout [1] is a technique for regularizing neural networks by randomly setting some output activations to zero during the forward pass. You will implement a dropout layer, provisions for which already exist in fully-connected network to optionally use dropout.
#
# [1] [Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012](https://arxiv.org/abs/1207.0580)
#
# Another blog with code to understand dropout: https://medium.com/analytics-vidhya/a-simple-introduction-to-dropout-regularization-with-code-5279489dda1e

# %% [markdown]
# ## Dropout: forward
# **Implement** the forward pass for dropout in `fully_connected_networks.py`. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes. Adjust your code in `FullyConnectedNet` to incorporate dropout.
#
# Run the following to test your dropout implementation. The mean of the output should be approximately the same during training and testing. During training the number of outputs set to zero should be approximately equal to the drop probability `p`, and during testing no outputs should be set to zero.

# %%
from fully_connected_networks import Dropout

cs6476.utils.reset_seed(903322690)
x = torch.randn(500, 500, dtype=torch.float64, device='cpu') + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = Dropout.forward(x, {'mode': 'train', 'p': p})
  out_test, _ = Dropout.forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean().item())
  print('Mean of train-time output: ', out.mean().item())
  print('Mean of test-time output: ', out_test.mean().item())
  print('Fraction of train-time output set to zero: ', (out == 0).type(torch.float32).mean().item())
  print('Fraction of test-time output set to zero: ', (out_test == 0).type(torch.float32).mean().item())
  print()

# %% [markdown]
# ## Dropout: backward
# Note: Backpropogation/Backward pass has already been implemented for your convinience. You can just run the below cell to test the overall implementation of the flow.

# %%
from fully_connected_networks import Dropout

cs6476.utils.reset_seed(903322690)
x = torch.randn(10, 10, dtype=torch.float64, device='cpu') + 10
dout = torch.randn_like(x)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 0}
out, cache = Dropout.forward(x, dropout_param)
dx = Dropout.backward(dout, cache)
dx_num = cs6476.grad.compute_numeric_gradient(lambda xx: Dropout.forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', cs6476.grad.rel_error(dx, dx_num))
# Out:
# dx relative error:  3.038735529404459e-09

# %% [markdown]
# # Fully-connected nets with dropout
# Test your drop-out implementation with Fully-Connected-NN. Run the following to numerically gradient-check your implementation. You should see errors less than `1e-5`, and different dropout rates should result different error values. We also provide an example code on how you can use `FullyConnectedNet` to run experiments and play with parameters.
# Note: An implemenation of `adam` optimizer is already provided in the `fully_connected_networks.py` file. Feel free to plug it as an optimizer for testing.

# %%
from fully_connected_networks import FullyConnectedNet

cs6476.utils.reset_seed(903322690)

N, D, H1, H2, C = 2, 15, 20, 30, 10
X = torch.randn(N, D, dtype=torch.float64, device='cpu')#
y = torch.randint(C, size=(N,), dtype=torch.int64, device='cpu')

for dropout in [0, 0.25, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dropout=dropout,
                            seed=0, dtype=torch.float64, device='cpu')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss.item())

  # Relative errors should be around e-5 or less.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = cs6476.grad.compute_numeric_gradient(f, model.params[name])
    print('%s relative error: %.2e' % (name, cs6476.grad.rel_error(grad_num, grads[name])))
  print()
# Out:
# Running check with dropout =  0
# Initial loss:  2.3007515088525388
# W1 relative error: 5.68e-08
# W2 relative error: 9.15e-08
# W3 relative error: 3.59e-08
# b1 relative error: 1.83e-07
# b2 relative error: 4.43e-08
# b3 relative error: 3.03e-09
#
# Running check with dropout =  0.25
# Initial loss:  2.3004334260411556
# W1 relative error: 1.16e-07
# W2 relative error: 7.72e-08
# W3 relative error: 4.19e-08
# b1 relative error: 2.36e-07
# b2 relative error: 3.58e-08
# b3 relative error: 2.65e-09
#
# Running check with dropout =  0.5
# Initial loss:  2.3031010098074645
# W1 relative error: 8.63e-08
# W2 relative error: 7.62e-08
# W3 relative error: 4.01e-08
# b1 relative error: 1.48e-07
# b2 relative error: 1.31e-08
# b3 relative error: 2.82e-09

# %%
from fully_connected_networks import FullyConnectedNet

# Train two identical nets, one with dropout and one without
cs6476.utils.reset_seed(903322690)
num_train = 40000
small_data = {
  'X_train': data_dict['X_train'][:num_train],
  'y_train': data_dict['y_train'][:num_train],
  'X_val': data_dict['X_val'],
  'y_val': data_dict['y_val'],
}


model = FullyConnectedNet([512], dropout=0.5, dtype=torch.float32, device='cpu')

solver = Solver(model, small_data,
                num_epochs=200, batch_size=512,
                update_rule=sgd_momentum,
                optim_config={
                  'learning_rate': 5e-3,
                },
                print_every=100000, print_acc_every=10,
                verbose=True, device='cpu')
solver.train()
print(solver)
# Out:
# (Time 0.12 sec; Iteration 1 / 15600) loss: 2.304128
# cpu
# (Epoch 0 / 200) train acc: 0.107000; val_acc: 0.102800
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 10 / 200) train acc: 0.422000; val_acc: 0.411200
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 20 / 200) train acc: 0.481000; val_acc: 0.457400
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 30 / 200) train acc: 0.518000; val_acc: 0.480400
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 40 / 200) train acc: 0.528000; val_acc: 0.498000
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 50 / 200) train acc: 0.573000; val_acc: 0.515200
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 60 / 200) train acc: 0.609000; val_acc: 0.523700
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 70 / 200) train acc: 0.595000; val_acc: 0.533000
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 80 / 200) train acc: 0.636000; val_acc: 0.538000
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 90 / 200) train acc: 0.667000; val_acc: 0.545500
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 100 / 200) train acc: 0.673000; val_acc: 0.549700
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 110 / 200) train acc: 0.681000; val_acc: 0.553200
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 120 / 200) train acc: 0.698000; val_acc: 0.558900
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 130 / 200) train acc: 0.691000; val_acc: 0.559100
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 140 / 200) train acc: 0.719000; val_acc: 0.558700
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 150 / 200) train acc: 0.722000; val_acc: 0.560900
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 160 / 200) train acc: 0.738000; val_acc: 0.562600
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 170 / 200) train acc: 0.739000; val_acc: 0.562000
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 180 / 200) train acc: 0.757000; val_acc: 0.559900
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 190 / 200) train acc: 0.786000; val_acc: 0.564000
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# cpu
# (Epoch 200 / 200) train acc: 0.810000; val_acc: 0.563200
# <cs6476.solver.Solver object at 0x7cf2eb03ece0>

# %% [markdown]
# ## Optimzation Experiments
# Congraturaltions you have all the code you need to train your fully connected neural network. Play around with things like network depth, dropout rate, hidden layer width and optimization algorithm to produce the best result. You can use the testing code provided above to set your own experiments. Once you have the optimal parameters create a function `optimal` in the file `fully_connected_networks.py` of the form:
# ```
# def optimal(data):
#     model = FullyConnectedNet([256], dropout=0.5, dtype=torch.float32, device='cuda')
#     solver = Solver(model, data,
#                     num_epochs=100, batch_size=512,
#                     update_rule=sgd_momentum,
#                     optim_config={
#                     'learning_rate': 5e-3,
#                     },
#                     print_every=100000, print_acc_every=10,
#                     verbose=True, device='cpu')
#     solver.train()# dont forget to comment this line in final submission after you have trained your model
#     solver.model.save(path)# dont forget to comment this line in final submision after you have saved your model
#     return solver
# ```
# Optimal parameters can be hardcoded. Autograder will use its own data of the format provided in above cell `small_data` for testing. Please save the model as `fcn_model.pth`. Make sure that device is set tp `cpu` in the final submission.
#
# ```
# def gtid():
#     return gtid
# ```
# also write a function which return your gtid as an integer value. Please note that you have to use your gtid to set seed for all experiments and code. It will be crucial for accurate testing over gradescope
